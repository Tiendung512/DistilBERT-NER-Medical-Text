# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/KLTN/NER-medical-text/")
# Out:
# Mounted at /content/drive

# %%
import re
import json
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import string
from collections import Counter
from wordcloud import WordCloud

import spacy
from spacy import displacy

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer


from nltk.probability import FreqDist
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data_dir = "data/MACCROBAT"

# %% [markdown]
# | Word   | Tag   |
# |--------|-------|
# | Patient| B-PER |
# | has    | O     |
# | diabetes | B-DIS |
# | type   | I-DIS |
# | 2      | I-DIS |
# | and    | O     |
# | high   | B-DIS |
# | blood  | I-DIS |
# | pressure | I-DIS |
# | .      | O     |

# %% [markdown]
# ## Loading Data

# %%
def get_doc_ids(data_dir):

    if not os.path.exists(data_dir):
        raise OSError(f"Directory {data_dir} does not exist.")

    doc_ids = []
    for doc in os.listdir(data_dir):
        doc_id = doc.split(".")[0]
        if doc_id not in doc_ids:
            doc_ids.append(doc_id)

    if not doc_ids:
        raise ValueError(f"No files with expected naming convention found in {data_dir}.")

    return doc_ids

# %%
doc_ids = get_doc_ids(data_dir)
print(f"Number of documents is {len(doc_ids)}")
# Out:
# Number of documents is 200

# %%
text_files = [f for f in os.listdir(data_dir) if f.endswith('.txt')]
ann_files = [f for f in os.listdir(data_dir) if f.endswith('.ann')]

text_ids = [f.split('.')[0] for f in text_files]
ann_ids = [f.split('.')[0] for f in ann_files]

# count number of files without annotations
missing_anns = 0
for text_id in text_ids:
    if text_id not in ann_ids:
        missing_anns += 1

# create bar chart
labels = ['Text files', 'Annotation files', 'Missing annotations']
counts = [len(text_files), len(ann_files), missing_anns]

plt.bar(labels, counts)
plt.title('Number of Files by Type')
plt.show()

# %%
import os

def load_txt_data(txt_dir, doc_ids):

    if not os.path.exists(txt_dir):
        raise OSError(f"Directory {txt_dir} does not exist.")

    data = {}

    for file_id in doc_ids:

        file_name = file_id + ".txt"

        with open(os.path.join(txt_dir, file_name), "r") as f:
            text = f.read()

        data[file_id] = {
                "text": text,
                "annotations": []
        }

    if not data:
        raise ValueError(f"No .txt files found in {txt_dir}.")

    return data

# %%
data = load_txt_data(data_dir, doc_ids)
print("data: {")
for doc_id in list(data.keys())[:3]:
    print(f"\t'{doc_id}': {{")
    text = data[doc_id]['text']
    annotations = data[doc_id]['annotations']
    print(f"\t\ttext:\t{text[:78]} .....")
    print(f"\t\tannotations: {annotations}")
    print("\t},")
print('\t....')
print("}")
# Out:
# data: {
# 	'15939911': {
# 		text:	CASE: A 28-year-old previously healthy man presented with a 6-week history of  .....
# 		annotations: []
# 	},
# 	'16778410': {
# 		text:	The patient was a 34-yr-old man who presented with complaints of fever and a c .....
# 		annotations: []
# 	},
# 	'17803823': {
# 		text:	A 23 year old white male with a 4 year history of Crohn's disease presented wi .....
# 		annotations: []
# 	},
# 	....
# }

# %% [markdown]
# #### Document Length Distribution

# %%
def get_doc_length_distribution(data):

    doc_lengths = []
    for doc_id in data:

            text = data[doc_id]['text']

            doc_length = len(text)
            doc_lengths.append(doc_length)

    return doc_lengths


doc_lengths = get_doc_length_distribution(data)

# plot the document length distribution
plt.hist(doc_lengths, bins=50)
plt.xlabel("Document Length")
plt.ylabel("Frequency")
plt.title("Document Length Distribution")
plt.show()

# %% [markdown]
# #### Sentence Count Distribution

# %%
def get_doc_sentence_counts(data):

    sentence_counts = []
    for doc_id in data:
        text = data[doc_id]['text']
        sentences = nltk.sent_tokenize(text)
        sentence_count = len(sentences)
        sentence_counts.append(sentence_count)

    return sentence_counts

# get the sentence counts
sentence_counts = get_doc_sentence_counts(data)

# plot the sentence count distribution
plt.hist(sentence_counts, bins=20)
plt.xlabel("Sentence Count")
plt.ylabel("Frequency")
plt.title("Sentence Count Distribution")
plt.show()

# %% [markdown]
# #### Word Frequency Distribution

# %%
def get_word_frequency_distribution(data):

    # Load stop words
    stop_words = set(stopwords.words('english'))

    # Tokenize text and count word frequency
    all_words = []
    for doc_id in data:
        text = data[doc_id]['text']
        words = nltk.word_tokenize(text)
        words = [w.lower() for w in words if w.isalpha() and w.lower() not in stop_words]
        all_words.extend(words)

    word_freq = dict(Counter(all_words))

    return word_freq

def plot_word_freq_distribution(word_freq):

    sorted_word_freq = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)

    words, freqs = zip(*sorted_word_freq)

    plt.figure(figsize=(12, 6))
    plt.bar(range(len(words)), freqs)

    plt.ylabel('Frequency')
    plt.title('Word Frequency Distribution')
    plt.show()

# %%
def get_word_frequencies(data):

    word_freq = FreqDist()
    stop_words = set(stopwords.words('english'))
    for doc_id in data:
        text = data[doc_id]['text']
        tokens = word_tokenize(text)

        # Remove stopwords and punctuation
        clean_tokens = [token.lower() for token in tokens if token.lower() not in stop_words and token not in string.punctuation]

        # Update word frequency distribution
        word_freq.update(clean_tokens)

    return word_freq

def plot_wordcloud(word_freq):

    wc = WordCloud(background_color='white', max_words=100, width=800, height=400)
    wc.generate_from_frequencies(word_freq)
    plt.figure(figsize=(12, 6))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.show()

word_freq = get_word_frequencies(data)
plot_wordcloud(word_freq)

# %%
import matplotlib.pyplot as plt
from collections import Counter
import collections


stop_words = set(stopwords.words('english'))

all_words = []
for doc_id in data:
    text = data[doc_id]['text']
    words = nltk.word_tokenize(text)
    words = [w.lower() for w in words if w.isalpha() and w.lower() not in stop_words]
    all_words.extend(words)

# Get the word frequency distribution
word_freq = Counter(all_words)
# Remove stop words
for stop_word in stop_words:
    del word_freq[stop_word]


# Get the 20 most common words
most_common = word_freq.most_common(20)

# Create a horizontal bar chart
words = [word[0] for word in most_common]
counts = [word[1] for word in most_common]
plt.barh(words, counts)

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Words")
plt.title("20 Most Common Words")

plt.show()

# %% [markdown]
# #### Non-ASCII Characters

# %%
non_ascii_characters = []
# Loop through each file in the folder
for doc_id in doc_ids:
    # Check if the file is a .txt file
    filename = f"{doc_id}.txt"
    # Open the file
    with open(os.path.join(data_dir, filename), 'r', encoding='utf-8') as file:
        # Read the file content
        file_content = file.read()
        # Find all non-ASCII characters using regular expressions
        non_ascii_chars = re.findall(r'[^\x00-\x7F]', file_content)
        # Print the filename and the special characters found
        if non_ascii_chars:
            print(f'File: {filename}, Non-ASCII characters: {non_ascii_chars}')
        non_ascii_characters.extend(non_ascii_chars)
# Out:
# File: 15939911.txt, Non-ASCII characters: ['–', '–', '–', '“', '”', '“', '”', '–', '“', '”']
# File: 17803823.txt, Non-ASCII characters: ['×', '×']
# File: 18236639.txt, Non-ASCII characters: ['μ', 'μ', '≤', 'μ']
# File: 18258107.txt, Non-ASCII characters: ['°', 'μ', '’', '–']
# File: 18416479.txt, Non-ASCII characters: ['\u200b', '×', '×', '×', '×', '\u200b']
# File: 18561524.txt, Non-ASCII characters: ['®', '®', '−', '°', '–', '–', 'μ', '–']
# File: 18666334.txt, Non-ASCII characters: ['®', '\u200b']
# File: 18787726.txt, Non-ASCII characters: ['×']
# File: 19009665.txt, Non-ASCII characters: ['α', '\u200b', '\u200b']
# File: 19307547.txt, Non-ASCII characters: ['’', '’', '–', '–', '®']
# File: 19610147.txt, Non-ASCII characters: ['\u200b', '\u200b', '\u200b', '\u200b', '\u200b', '\u200b']
# File: 19860006.txt, Non-ASCII characters: ['\u200b', '\u200b', '\u200b']
# File: 19860007.txt, Non-ASCII characters: ['×', '×', '\u200b', '×', '\u200b', '×', '\u200b', 'β', '\u200b', '\u200b', 'β', 'β']
# File: 19860925.txt, Non-ASCII characters: ['×', '\u200b', '\u200b']
# File: 20146086.txt, Non-ASCII characters: ['–', '–']
# File: 20671919.txt, Non-ASCII characters: ['\u2009', '\u2009', '\u2009']
# File: 20977862.txt, Non-ASCII characters: ['\u200b', '\u200b']
# File: 21067996.txt, Non-ASCII characters: ['\u2009', '\u2009', '\u2009', '×', '×']
# File: 21254744.txt, Non-ASCII characters: ['–', '–', '–', '–', '–', '–', '–', '–', '–', '–', '–', '–', '–', 'Ⅱ']
# File: 21308977.txt, Non-ASCII characters: ['–', '–', '’', '–', '−']
# File: 21477357.txt, Non-ASCII characters: ['°', '\u200b', '×', '\u200b', '\u200b', '\u200b']
# File: 21505579.txt, Non-ASCII characters: ['–', '–', 'Ⅱ', '–', '–', '–', '–', '–']
# File: 21527041.txt, Non-ASCII characters: ['\u200b', '\u200b']
# File: 21672201.txt, Non-ASCII characters: ['≥', '\u200b', '°', '\u200b']
# File: 21720478.txt, Non-ASCII characters: ['–', '–', '–', '®', '–', '®', '“', '”']
# File: 21923918.txt, Non-ASCII characters: ['\u200b', '\u200b']
# File: 22218279.txt, Non-ASCII characters: ['–', 'β', 'μ']
# File: 22514576.txt, Non-ASCII characters: ['–', '–', '–', '–', '–', '–']
# File: 22515939.txt, Non-ASCII characters: ['\u200b']
# File: 22520024.txt, Non-ASCII characters: ['\u2009', '\u2009', '\u2009', '\u200b', '\u2009', '\u2009', '\u2009']
# File: 22665582.txt, Non-ASCII characters: ['’', '×']
# File: 22719160.txt, Non-ASCII characters: ['β']
# File: 22781096.txt, Non-ASCII characters: ['−', '\u2009', 'μ', '–', '\u2009', 'μ', '–', '\u2009', '\u2009', '–', '\u2009', '\u2009', '\u2009', '\u2009', '\u2009', '\u2009', '\u2009', 'μ', '\u2009', 'μ']
# File: 22791498.txt, Non-ASCII characters: ['\u200b']
# File: 22814979.txt, Non-ASCII characters: ['\u2005', '\u2005', '\u2005', '\u2005', 'μ', '–', '\u2005', 'μ', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', 'μ', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', 'β', '\u2005', '–', '\u2005', '\u2005', 'α', 'β']
# File: 23035161.txt, Non-ASCII characters: ['\u2005', '\u2005', '\u2005', '°', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', 'µ', '\u2005', 'µ', '\u2005', '\u2005', 'µ', '\u2005', '×', '\u2005', '\u2005', '\u2005', 'µ', '\u200b', 'δ', '\u2005', '\u2005']
# File: 23076693.txt, Non-ASCII characters: ['°', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005']
# File: 23155491.txt, Non-ASCII characters: ['‘']
# File: 23242090.txt, Non-ASCII characters: ['\u2005', '\u2005', 'ö', '\u2005', '—', '—', '\u2005']
# File: 23312850.txt, Non-ASCII characters: ['–', '–']
# File: 23468586.txt, Non-ASCII characters: ['μ', '–', 'μ', 'μ', '–', 'μ', 'μ', 'μ', 'μ', 'μ']
# File: 23678274.txt, Non-ASCII characters: ['µ', 'µ', 'µ', 'µ']
# File: 23864579.txt, Non-ASCII characters: ['™']
# File: 23897372.txt, Non-ASCII characters: ['\u2005', '\u2005', '‘', '’', 'λ', '\u2005', '–', '\u2005', '\u2005', '\u2005', '−', 'κ', 'λ', '—', 'β', '—']
# File: 24161539.txt, Non-ASCII characters: ['–', '–']
# File: 24294397.txt, Non-ASCII characters: ['’', '’', '\u200b', '’', '’', '’', '’', '’', '’']
# File: 24518095.txt, Non-ASCII characters: ['–', '′', '′', '′']
# File: 24526194.txt, Non-ASCII characters: ['\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u200b']
# File: 24654246.txt, Non-ASCII characters: ['\u2005', '‘', '’', '–', '\u2005', '\u2005']
# File: 24781756.txt, Non-ASCII characters: ['\u2009', '\u2009', '\u2009', '–', '\u2009', '\u2009', 'μ', '–', '\u2009', 'μ', '\u2009', 'μ', '\u2009', 'μ', '\u2009']
# File: 24898994.txt, Non-ASCII characters: ['\u2005', 'ü']
# File: 24957905.txt, Non-ASCII characters: ['’', '’']
# File: 25024632.txt, Non-ASCII characters: ['×', '\u200b', '\u200b']
# File: 25139918.txt, Non-ASCII characters: ['\u2005', '\u2005', '\u2005', '\u2005', '−', '\u2005', '\u2005', '\u200b', '\u2005', '\u2005', '\u2005']
# File: 25210224.txt, Non-ASCII characters: ['×', '×', '\u200b']
# File: 25293719.txt, Non-ASCII characters: ['\u2009', '\u2009', '\u2009', '\u2009', '\u2009', '\u2009', '\u2009', '–', '\u2009', '\u2009', '\u2009', 'μ', '\u2009', '\u2009', '\u2009', '–', '\u2009', '\u2009', '–', '\u2009', '\u2009', '\u2009', '∼', '\u2009', '\u2009']
# File: 25410034.txt, Non-ASCII characters: ['\u2005', '‘', '’', '‘', '’', '‘', '’', '\u2005', '\u2005', '\u2005', '\u2005']
# File: 25410883.txt, Non-ASCII characters: ['–', '’']
# File: 25572898.txt, Non-ASCII characters: ['–', 'µ', 'µ', '–', '–', '×', 'μ', '–', '×', 'μ', '\u200b']
# File: 25661749.txt, Non-ASCII characters: ['‘', '’', '\u2005', '\u2005', '‘', '’', '\u2005', '×', '\u2005', '×', '\u2005', '–', '\u2005', '\u2005', '\u2005', 'µ', '\u2005', '\u2005']
# File: 25721834.txt, Non-ASCII characters: ['\u2005', '\u2005', '\u2005', '–', '\u2005', '–', '\u2005', '–', '–', '×', '–', '×', '–', '×', '–', '’', '\u2005', '\u2005', '\u2005', 'µ', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', 'µ', '\u2005', '\u2005', 'µ', '–']
# File: 25743872.txt, Non-ASCII characters: ['\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '°', '\u2005', '\u2005']
# File: 25759562.txt, Non-ASCII characters: ['×', '\u200b', '\u200b', '×', '×', '\u200b']
# File: 25853982.txt, Non-ASCII characters: ['×']
# File: 25858931.txt, Non-ASCII characters: ['\u2005', '\u2005', '\u2005', 'µ', '\u2005', '\u2005', '\u2005', '–', '\u2005', '\u2005', '–', '\u2005', '–', '\u2005', '–', '–', '–', '\u200b', '\u2005', '\u2005', '\u200b', '\u2005', '\u2005', '\u2005', '\u2005', '–']
# File: 25884600.txt, Non-ASCII characters: ['–', '–', '–', '\u2009', '\u2009', '×', 'μ', 'μ']
# File: 25926582.txt, Non-ASCII characters: ['\u2005', '\u2005', '—', '\u2005', 'µ', '\u2005']
# File: 25934795.txt, Non-ASCII characters: ['–', '–', '–', '–', '–', '\u200b', '\u200b']
# File: 26106249.txt, Non-ASCII characters: ['’', '’', '’']
# File: 26175648.txt, Non-ASCII characters: ['°', '–', '\u200b']
# File: 26228535.txt, Non-ASCII characters: ['μ', '–', '’']
# File: 26257516.txt, Non-ASCII characters: ['λ', '–', 'κ']
# File: 26266396.txt, Non-ASCII characters: ['\u200b', '\u200a', '\u200b', '\u200b', '“', '”', '\u200b', '\u200b']
# File: 26309459.txt, Non-ASCII characters: ['µ', 'µ']
# File: 26313770.txt, Non-ASCII characters: ['α', '\u200a', 'μ', '\u200a', '\u200a', '×', '\u200a', '\u200a', '\u200a', '×', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '×', '\u200a', '\u200a', 'μ', '\u200a', '×', '\u200a', '\u200a', 'μ', '\u200a', '×', '\u200a', 'μ', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '×', '\u200a', '\u200a', 'μ', '\u200a', '×', '\u200a', '\u200a', 'μ', '\u200b', '\u200a', '×', '\u200a', '\u200a', 'μ', '\u200a']
# File: 26336183.txt, Non-ASCII characters: ['\u2005', '–', '\u2005', '–', '\u2005', '–', 'γ', '\u2005', '\u2005', 'μ', '\u2005', 'μ', '–', '\u2005', '–', '×', '\u2005', '–', 'é', '\u2005', '\u2005', '\u2005', 'μ', '–', '\u2005', 'μ', '–', '\u2005', '\u2005', '\u2005', 'μ', '\u2005', 'μ', '\u2005']
# File: 26350418.txt, Non-ASCII characters: ['–', '–', '–', '–', '–', '–', '–', '–']
# File: 26361431.txt, Non-ASCII characters: ['\u200b', '\u200b', '×', '\u200b', '\u200b']
# File: 26361640.txt, Non-ASCII characters: ['μ', 'μ', '\u200b', '’']
# File: 26395443.txt, Non-ASCII characters: ['°', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '’', '®', '®', '®']
# File: 26444414.txt, Non-ASCII characters: ['–', '\u2009', '×', '\u2009']
# File: 26445413.txt, Non-ASCII characters: ['\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009']
# File: 26469535.txt, Non-ASCII characters: ['–']
# File: 26474553.txt, Non-ASCII characters: ['\u2009', '\u2009', '−', '®', '\u2009', '\u2009', '−', '\u2009', '\u2009']
# File: 26523273.txt, Non-ASCII characters: ['℃', 'α', 'β', 'β']
# File: 26530965.txt, Non-ASCII characters: ['–', '–', '∼', '–', '–']
# File: 26584481.txt, Non-ASCII characters: ['β', 'μ', 'μ', 'μ', 'μ', 'μ', 'α', 'β', 'μ', 'μ', 'μ', 'μ']
# File: 26664317.txt, Non-ASCII characters: ['–']
# File: 26670309.txt, Non-ASCII characters: ['’', '’', '®', '®', '°', '’', '’', '’']
# File: 26675562.txt, Non-ASCII characters: ['–']
# File: 26683938.txt, Non-ASCII characters: ['μ', '\u200a', 'μ', '\u200b']
# File: 26692730.txt, Non-ASCII characters: ['−', '×', '°', '×', '°', 'μ', '\u200b']
# File: 26714786.txt, Non-ASCII characters: ['\u2009', '\u2009', '–', '’', '’']
# File: 27004009.txt, Non-ASCII characters: ['\u200b', '\u200b', '\u200b', '×', '\u200b', '×', '\u200b', '\u200b']
# File: 27057898.txt, Non-ASCII characters: ['\u200b', '\u200b', '\u200b', '\u200b', '\u200b']
# File: 27059701.txt, Non-ASCII characters: ['\u2009', '×', '\u2009', '’', '’', '\u200b']
# File: 27064109.txt, Non-ASCII characters: ['×', '–', '–', '–', 'μ', '–', '–', '’', '’', 'β', 'λ', '’', 'β']
# File: 27100441.txt, Non-ASCII characters: ['°', '\u200a', '–', '–', '\u200b', '–', '–', '\u200b', '\u200b', '\u200b', '\u200b', '\u200a', 'μ', '–', '\u200a', 'μ', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a', '\u200a', 'μ', '–', '\u200a', 'μ', '\u200a', 'μ', '–', '\u200a', 'μ', '\u200a', '\u200a', '\u200b', '\u200b', '–', '\u200a', '\u200a', '\u200a', 'α', '\u200a', '\u200b', '–', '\u200a', '\u200a', '\u200a', '\u200a']
# File: 27130218.txt, Non-ASCII characters: ['μ', '\u200b']
# File: 27196481.txt, Non-ASCII characters: ['\u200b', '\u200b']
# File: 27661040.txt, Non-ASCII characters: ['\u200a', 'μ', '\u200a', 'μ', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', 'μ', '\u200a', 'μ', '\u200a', 'μ', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', 'μ', '\u200a', 'μ']
# File: 27683825.txt, Non-ASCII characters: ['\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005']
# File: 27741115.txt, Non-ASCII characters: ['°', '\u200b', '–', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', 'μ']
# File: 27749582.txt, Non-ASCII characters: ['\u200b', '\u200a', 'μ', '\u200a', '\u200a', '–']
# File: 27793101.txt, Non-ASCII characters: ['\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009']
# File: 27821134.txt, Non-ASCII characters: ['“', '”', '’', '“', '”', '“', '”', '’', '≥']
# File: 27842595.txt, Non-ASCII characters: ['\u200b', '\u200b']
# File: 27842605.txt, Non-ASCII characters: ['ɤ', '\u200b', '“', '”', '\u2009', '×', '\u2009', '\u2009', '×', '\u2009', '\u200b', '–', '–', '–', '\u200b']
# File: 27846860.txt, Non-ASCII characters: ['°', '–', '’', '’', '’']
# File: 27904130.txt, Non-ASCII characters: ['’', '’']
# File: 27906105.txt, Non-ASCII characters: ['\u2009', '×', '\u2009', '\u2009', '×', '\u2009']
# File: 27928148.txt, Non-ASCII characters: ['°', '–', '–', '–', '–', '–']
# File: 27974938.txt, Non-ASCII characters: ['°']
# File: 27980261.txt, Non-ASCII characters: ['×']
# File: 27980272.txt, Non-ASCII characters: ['℃', 'μ', 'μ', 'μ', 'μ', '℃']
# File: 27990013.txt, Non-ASCII characters: ['’', '×']
# File: 28033278.txt, Non-ASCII characters: ['μ', '–', 'μ', '\u200a', '–', '\u200a', 'μ', '–', 'μ', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a', '\u200a', '–', '–', 'μ', '\u200a', '–', '\u200a', '\u200a']
# File: 28057913.txt, Non-ASCII characters: ['’', '’', '≤', '’', '–', '–', '–']
# File: 28079821.txt, Non-ASCII characters: ['μ', '\u200a', 'μ', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '½', '\u200a', 'μ', '\u200a', '–', 'μ']
# File: 28090049.txt, Non-ASCII characters: ['℃', 'μ', 'μ']
# File: 28100235.txt, Non-ASCII characters: ['’', '\u2009', '×', '\u2009', '–', '–', '’']
# File: 28100279.txt, Non-ASCII characters: ['°', '’']
# File: 28103924.txt, Non-ASCII characters: ['–', '–', '–', '’', '’', '’', '–', '’']
# File: 28115731.txt, Non-ASCII characters: ['–', '°', '°', '−', '’', '−', '–', '\u200b', '’']
# File: 28120581.txt, Non-ASCII characters: ['×', '×', '×', '×']
# File: 28121940.txt, Non-ASCII characters: ['–', '\u200a', '\u200b']
# File: 28151860.txt, Non-ASCII characters: ['\u200a', '\u200a']
# File: 28151882.txt, Non-ASCII characters: ['°', 'ü', '\u200a', '\u200a', '\u200a', '\u200a', '°', '°', '°']
# File: 28151916.txt, Non-ASCII characters: ['\u200a', '×', '\u200a', '\u200a', '×', '\u200a', '\u200a']
# File: 28154281.txt, Non-ASCII characters: ['×', '×', '×', '×', 'μ', 'μ']
# File: 28154287.txt, Non-ASCII characters: ['°', 'μ']
# File: 28154669.txt, Non-ASCII characters: ['’']
# File: 28173879.txt, Non-ASCII characters: ['°', 'μ', '®', '–', '’', '®', '’', '’']
# File: 28190872.txt, Non-ASCII characters: ['™']
# File: 28193213.txt, Non-ASCII characters: ['’', '’', '’']
# File: 28196820.txt, Non-ASCII characters: ['–', '–', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '–', '\u2005', '\u2005', '\u2005', '€', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', 'µ', '\u2005', '\u2005', '\u2005', 'µ', '–', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', 'µ', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005', '\u2005']
# File: 28202862.txt, Non-ASCII characters: ['™', 'μ', '™']
# File: 28202865.txt, Non-ASCII characters: ['°']
# File: 28202869.txt, Non-ASCII characters: ['μ', '・', '・', '・', '・']
# File: 28207542.txt, Non-ASCII characters: ['\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '×', '\u200a', '–', '\u200a', '×', '\u200a', '\u200a', '–', '\u200a', '–', '\u200a', '–', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '×', '\u200a', '–', '\u200a', '×', '\u200a', '\u200a', '×', '\u200a', '–', '\u200a', '–', '\u200a', '–', '\u200a', '–', '\u200a', '–', '\u200a', '\u200a', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200b']
# File: 28216610.txt, Non-ASCII characters: ['–', '°', '×', '×', '–']
# File: 28239141.txt, Non-ASCII characters: ['°', '°', '×', '×', '–', '–', '–']
# File: 28248858.txt, Non-ASCII characters: ['\u200a', '\u200a', '\u200b', '\u200a', '×', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a']
# File: 28248891.txt, Non-ASCII characters: ['–', 'π', 'π', 'α', 'α', '–', '\u200a', '\u200a', '\u200a', '–', '–', '–']
# File: 28250304.txt, Non-ASCII characters: ['μ', '\u200b', '×']
# File: 28250406.txt, Non-ASCII characters: ['–', '–']
# File: 28265107.txt, Non-ASCII characters: ['–']
# File: 28272214.txt, Non-ASCII characters: ['\u200a', '×', '\u200a', '\u200a', '\u200a', '–', '\u200a', '–', '–', '–', '\u200a', '\u200a', '\u200a', '–', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a']
# File: 28272235.txt, Non-ASCII characters: ['’', '\u200a', '\u200a', '×', '\u200a', '–', '\u200a', '×', '\u200a', '\u200a', '–', '\u200a', '\u200a', '\u200a', '–', '–', '’']
# File: 28296749.txt, Non-ASCII characters: ['×', '×', '\u200a', '×', '\u200a']
# File: 28296775.txt, Non-ASCII characters: ['–', '\u200a', '\u200a', '×', '×', '\u200a', '“', '”', '\u200a', '“', '”']
# File: 28320420.txt, Non-ASCII characters: ['×', '×']
# File: 28353556.txt, Non-ASCII characters: ['\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '–', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '–', '\u200a']
# File: 28353558.txt, Non-ASCII characters: ['γ', '\u200a']
# File: 28353561.txt, Non-ASCII characters: ['\u200a', '°', '\u200a', '\u200a', '\u200a', 'μ', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a']
# File: 28353569.txt, Non-ASCII characters: ['\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200b', '\u200a', '×', '\u200a', '\u200b']
# File: 28353588.txt, Non-ASCII characters: ['×', '×', '\u200a', '\u200a', '\u200a', '×', '\u200a', '\u200a', '×', '\u200a', '\u200a', '–', '\u200a', '\u200a', '–']
# File: 28353596.txt, Non-ASCII characters: ['−', '−', '−', '\u200b', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a']
# File: 28353604.txt, Non-ASCII characters: ['\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '–', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '’', '’', '–', '–']
# File: 28353613.txt, Non-ASCII characters: ['\u200a', '°', '\u200a', '\u200a', '\u200a', '°', '\u200a', '\u200a', '\u200a', '\u200a', '\u200b', '\u200a', '\u200a']
# File: 28383413.txt, Non-ASCII characters: ['–', '\u200a', '\u200a', '\u200a', '∗', '°', '∗', '°', '\u200a', '\u200a', '\u200a', '\u200a', 'μ', '–', '\u200a', 'μ', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a', '\u200a', '–', '\u200a']
# File: 28403086.txt, Non-ASCII characters: ['\u200b', '\u200a', '\u200b']
# File: 28403092.txt, Non-ASCII characters: ['\u200a', '×', '\u200a', '\u200a', '×', '\u200a', '\u200a', '“', '”', '\u200a', '\u200a', 'μ', '\u200a', 'μ', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', 'μ', '\u200a', 'μ', '\u200a', '\u200a', 'μ', '–', '\u200a', 'μ', '–', '\u200a', 'μ', '\u200a', '\u200a', '\u200a', '\u200a']
# File: 28403099.txt, Non-ASCII characters: ['\u200a', '\u200a', '\u200a', '°', '\u200a', '\u200a', '\u200a', '\u200a', '–', '\u200a', '\u200a', '×', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200b', '–', '–', '–', '–', '\u200a', '\u200a', '\u200a']
# File: 28422883.txt, Non-ASCII characters: ['\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a', 'μ', '\u200a']
# File: 28538413.txt, Non-ASCII characters: ['\u200a', '\u200a', '×', '\u200a', '\u200a', '\u200a', '\u200a', '\u200a']
# File: 28595573.txt, Non-ASCII characters: ['\u200b', '–', '–', '\u2009', '\u2009', '\u2009', '\u2009', '\u2009', '\u2009']
# File: 28767567.txt, Non-ASCII characters: ['–', '\u200a', '×', '\u200a', '\u200a', '×', '\u200a', '\u200a', '\u200a', '×', '\u200a', '\u200a', '\u200a', '×', '\u200a', '\u200a', '×', '\u200a', '\u200a', '–']

# %%
', '.join(set(non_ascii_characters))
# Out:
# 'µ, γ, \u200b, ∼, α, é, μ, λ, ≥, ≤, \u200a, €, Ⅱ, ∗, ü, ™, δ, –, \u2009, π, ®, β, ½, ”, ö, κ, −, °, —, ・, ’, “, ×, ℃, ‘, ′, \u2005, ɤ'

# %% [markdown]
# #### Transliterate non-ASCII characters to their closest ASCII equivalents.

# %%
# !pip install unidecode
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
from unidecode import unidecode

for char in set(non_ascii_characters):
    print(f"{char}  {unidecode(char)}")
# Out:
# µ  u
# γ  g
# ​
# ∼  ~
# α  a
# é  e
# μ  m
# λ  l
# ≥  >=
# ≤  <=
#
# €  EUR
# Ⅱ  II
# ∗  *
# ü  u
# ™  (tm)
# δ  d
# –  -
#
# π  p
# ®  (r)
# β  b
# ½   1/2
# ”  "
# ö  o
# κ  k
# −  -
# °  deg
# —  --
# ・  *
# ’  '
# “  "
# ×  x
# ℃
# ‘  '
# ′  '
#
# ɤ  u

# %% [markdown]
# ## Load the ann files

# %%
sample_ann_file = doc_id + ".ann"
lines = []
with open(os.path.join(data_dir, sample_ann_file)) as f:
    for line in f.readlines():
        lines.append(line)
print("")
for line in lines[:6]:
    print(line.strip())
# Out:
# T1	Age 2 24	4 and a half years old
# T2	Sex 25 29	male
# T3	Clinical_event 36 45	presented
# E1	Clinical_event:T3
# T4	Nonbiological_location 53 61	hospital
# R1	MODIFY Arg1:T4 Arg2:E1

# %% [markdown]
# All the 200 .ann files are in brat standoff format

# %%
# !pwd
# Out:
# /content/drive/MyDrive/KLTN/NER-medical-text

# %%
tags = []

for doc_id in doc_ids:
    ann_file = doc_id + ".ann"
    with open(os.path.join(data_dir, ann_file)) as f:
        for line in f.readlines():
            tags.append(line.split("\t")[0][0])

set(tags)
# Out:
# {'#', '*', 'A', 'E', 'R', 'T'}

# %%
flag = False
for doc_id in doc_ids:
    ann_file = doc_id + ".ann"
    with open(os.path.join(data_dir, ann_file)) as f:
        for line in f.readlines():
            if line.startswith('T'):
                label = line.split('\t')[1].split()[0]
                start_end_pair = line.split('\t')[1].split()[1:]
                if len(start_end_pair) > 2:
                    print('There exists more than one start end offset pairs')
                    print(' '.join(start_end_pair))
# Out:
# There exists more than one start end offset pairs
# 1366 1373;1386 1404
# There exists more than one start end offset pairs
# 341 350;357 358
# There exists more than one start end offset pairs
# 2001 2005;2034 2037
# There exists more than one start end offset pairs
# 2114 2133;2139 2143
# There exists more than one start end offset pairs
# 2428 2438;2444 2463
# There exists more than one start end offset pairs
# 2428 2438;2472 2499
# There exists more than one start end offset pairs
# 464 465;477 484
# There exists more than one start end offset pairs
# 467 468;477 484
# There exists more than one start end offset pairs
# 1610 1633;1652 1658
# There exists more than one start end offset pairs
# 2533 2540;2559 2570
# There exists more than one start end offset pairs
# 2542 2547;2559 2570
# There exists more than one start end offset pairs
# 1994 2004;2021 2029
# There exists more than one start end offset pairs
# 1644 1653;1673 1684
# There exists more than one start end offset pairs
# 701 714;730 735
# There exists more than one start end offset pairs
# 4085 4093;4103 4108
# There exists more than one start end offset pairs
# 3117 3124;3135 3141
# There exists more than one start end offset pairs
# 474 481;490 503
# There exists more than one start end offset pairs
# 2831 2851;2858 2859
# There exists more than one start end offset pairs
# 2637 2653;2667 2674
# There exists more than one start end offset pairs
# 2296 2320;2327 2335
# There exists more than one start end offset pairs
# 2362 2371;2375 2377
# There exists more than one start end offset pairs
# 2362 2371;2383 2386
# There exists more than one start end offset pairs
# 1746 1813;1814 1845;1846 1878;1879 1921;1922 1950;1951 1976
# There exists more than one start end offset pairs
# 2015 2024;2052 2061
# There exists more than one start end offset pairs
# 704 715;721 726
# There exists more than one start end offset pairs
# 828 835;861 879
# There exists more than one start end offset pairs
# 849 857;861 879
# There exists more than one start end offset pairs
# 315 317;319 330
# There exists more than one start end offset pairs
# 297 313;319 330
# There exists more than one start end offset pairs
# 606 621;641 647
# There exists more than one start end offset pairs
# 1017 1032;1052 1058
# There exists more than one start end offset pairs
# 1316 1318;1328 1336
# There exists more than one start end offset pairs
# 1386 1391;1408 1412
# There exists more than one start end offset pairs
# 606 621;641 647
# There exists more than one start end offset pairs
# 1101 1111;1121 1126
# There exists more than one start end offset pairs
# 1101 1111;1131 1137
# There exists more than one start end offset pairs
# 1439 1446;1457 1476
# There exists more than one start end offset pairs
# 2352 2357;2367 2371
# There exists more than one start end offset pairs
# 2873 2880;2902 2912
# There exists more than one start end offset pairs
# 2873 2880;2917 2926
# There exists more than one start end offset pairs
# 1645 1650;1660 1673
# There exists more than one start end offset pairs
# 1246 1252;1261 1274
# There exists more than one start end offset pairs
# 1596 1600;1628 1631
# There exists more than one start end offset pairs
# 1657 1661;1690 1693
# There exists more than one start end offset pairs
# 2306 2308;2316 2323
# There exists more than one start end offset pairs
# 900 905;915 918
# There exists more than one start end offset pairs
# 926 929;938 939
# There exists more than one start end offset pairs
# 4047 4155;4156 4238
# There exists more than one start end offset pairs
# 1557 1559;1560 1567
# There exists more than one start end offset pairs
# 2186 2188;2189 2196
# There exists more than one start end offset pairs
# 2427 2429;2430 2437
# There exists more than one start end offset pairs
# 2552 2559;2585 2654
# There exists more than one start end offset pairs
# 535 538;546 550
# There exists more than one start end offset pairs
# 1251 1257;1274 1276
# There exists more than one start end offset pairs
# 1739 1743;1761 1766

# %%
entity_type_counts = {}
for doc_id in doc_ids:
    ann_file = doc_id + ".ann"
    with open(os.path.join(data_dir, ann_file)) as f:
        for line in f:
            if line.startswith("T"):
                entity_type = line.split()[1]
                entity_type_counts[entity_type] = entity_type_counts.get(entity_type, 0) + 1

entity_types = list(entity_type_counts.keys())
counts = list(entity_type_counts.values())

# sort by count in descending order
entity_types_sorted = [x for _, x in sorted(zip(counts, entity_types), reverse=True)]
counts_sorted = sorted(counts, reverse=True)

# only keep top 20 entities for visualization
entity_types_top = entity_types_sorted[:20]
counts_top = counts_sorted[:20]

fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(entity_types_top, counts_top)
ax.set_xticks(range(len(entity_types_top)))
ax.set_xticklabels(entity_types_top, rotation=45, ha="right")
ax.set_ylabel("Count")
ax.set_title("Distribution of Entity Types")
plt.show()

# %%
def splitting_tokens(file_id, start, end, hyphen_split=True):
    """
    Splits a token into its constituent words and returns a list of tokens along with the corresponding
    ranges for each word in the original text.

    Args:
        text (str): The original text containing the token to be split.
        start (int): The starting index of the token in the text.
        end (int): The ending index of the token in the text.

    Returns:
        A tuple containing:
            - a list of the constituent words of the token
            - a list of lists containing the start and end indices of each word in the original token
    """
    text = data[file_id]['text']
    token = text[start:end]

    extra_sep = ['\u200a']
    if hyphen_split:
        extra_sep += ['-', '\u2010', '\u2011', '\u2012', '\u2013', '\u2014', '\u2015', '\u2212', '\uff0d']

    new_range = []
    tokens = []

    curr = start
    new_start = None

    for c in token + " ":
        if c.isspace() or c in extra_sep:
            if new_start:
                new_range.append([new_start, curr])
                tokens.append(text[new_start:curr])
                new_start = None
        elif not new_start:
            new_start = curr
        curr += 1

    return tokens, new_range

# %%
def load_ann_data(ann_dir, doc_ids, data, hyphen_split=True):
    """
    Loads annotations from a directory of .ann files and adds them to the corresponding
    files in a data dictionary.

    Args:
        ann_dir (str): Path to the directory containing the .ann files.
        data (dict): A dictionary of file IDs (strings) mapped to their corresponding data,
        where each data item is represented by a nested dictionary containing the following key-value pairs:
            - "text": the full text of the file as a string.
            - "annotations": a list of annotations for the file, where each annotation is represented
            by a dictionary containing the following key-value pairs:
                - "label": the label of the annotation as a string.
                - "start": the starting character index of the annotation as an integer.
                - "end": the ending character index of the annotation as an integer.

    Returns:
        data - modified the input dictionary
    """
    for doc_id in doc_ids:

        file_name = doc_id + ".ann"

        with open(os.path.join(ann_dir, file_name), "r") as f:

            annotations = []

            for line in f:
                if line.startswith("T"):
                    fields = line.strip().split("\t")
                    if len(fields[1].split(" ")) > 1:
                        label = fields[1].split(" ")[0]

                        # Extracting start end indices (Few annotations contain more than one disjoint ranges)
                        start_end_range = [
                            list(map(int, start_end.split()))
                            for start_end in ' '.join(fields[1].split(" ")[1:]).split(';')
                        ]

                        start_end_range_fixed = []
                        for start, end in start_end_range:
                            tokens, start_end_split_list = splitting_tokens(doc_id, start, end,
                                                                                  hyphen_split)
                            start_end_range_fixed.extend(start_end_split_list)

                        # Adding labels, start, end to annotations
                        for start, end in start_end_range_fixed:
                            annotations.append({
                                "label": label,
                                "start": start,
                                "end": end
                            })
            # sort annotations based on 'start' key before adding it to our dataset
            annotations = sorted(annotations, key=lambda x: (x['start'], x['label']))
            data[doc_id]["annotations"] = annotations

    return data

# %% [markdown]
# **Loading Data into _data_ dictionary**

# %%
data = load_ann_data(data_dir, doc_ids, data)

# %% [markdown]
# **Looking at the _data_ dictionary**

# %%
for doc_id in list(data.keys())[:3]:
    text = data[doc_id]['text']
    annotations = data[doc_id]['annotations']
    print(f"text:\n{text[:40]} .....")
    print(f"annotations:\n{annotations[:2]} .....")
# Out:
# text:
# CASE: A 28-year-old previously healthy m .....
# annotations:
# [{'label': 'Age', 'start': 8, 'end': 10}, {'label': 'Age', 'start': 11, 'end': 15}] .....
# text:
# The patient was a 34-yr-old man who pres .....
# annotations:
# [{'label': 'Age', 'start': 18, 'end': 20}, {'label': 'Age', 'start': 21, 'end': 23}] .....
# text:
# A 23 year old white male with a 4 year h .....
# annotations:
# [{'label': 'Age', 'start': 2, 'end': 4}, {'label': 'Age', 'start': 5, 'end': 9}] .....

# %% [markdown]
# Successfully loaded data into dictionary which is in the below format
#
# ```
# data : {
#
#     'file_id': {
#
#         'text': text_data,
#         'annotations': [
#                         {'label': label, 'start': start, 'end': end},
#                         {'label': label, 'start': start, 'end': end},
#                         {'label': label, 'start': start, 'end': end},
#                         {'label': label, 'start': start, 'end': end},
#                         {'label': label, 'start': start, 'end': end},
#                         ....
#                        ],
#     'file_id': {
#
#         'text': text_data,
#         'annotations': [
#                         {'label': label, 'start': start, 'end': end},
#                         {'label': label, 'start': start, 'end': end},
#                         {'label': label, 'start': start, 'end': end},
#                         {'label': label, 'start': start, 'end': end},
#                         {'label': label, 'start': start, 'end': end},
#                         ....
#                        ],
#
#     },
#
#     ......
#
# }
# ```

# %%
entities = set()
for doc_id, doc in data.items():
    for ann in doc['annotations']:
        entities.add(ann['label'])
entities
# Out:
# {'Activity',
#  'Administration',
#  'Age',
#  'Area',
#  'Biological_attribute',
#  'Biological_structure',
#  'Clinical_event',
#  'Color',
#  'Coreference',
#  'Date',
#  'Detailed_description',
#  'Diagnostic_procedure',
#  'Disease_disorder',
#  'Distance',
#  'Dosage',
#  'Duration',
#  'Family_history',
#  'Frequency',
#  'Height',
#  'History',
#  'Lab_value',
#  'Mass',
#  'Medication',
#  'Nonbiological_location',
#  'Occupation',
#  'Other_entity',
#  'Other_event',
#  'Outcome',
#  'Personal_background',
#  'Qualitative_concept',
#  'Quantitative_concept',
#  'Severity',
#  'Sex',
#  'Shape',
#  'Sign_symptom',
#  'Subject',
#  'Texture',
#  'Therapeutic_procedure',
#  'Time',
#  'Volume',
#  'Weight'}

# %%
colors = {"Activity": "#f9d5e5",
          "Administration": "#f7a399",
          "Age": "#f6c3d0",
          "Area": "#fde2e4",
          "Biological_attribute": "#d5f5e3",
          "Biological_structure": "#9ddfd3",
          "Clinical_event": "#77c5d5",
          "Color": "#a0ced9",
          "Coreference": "#e3b5a4",
          "Date": "#f1f0d2",
          "Detailed_description": "#ffb347",
          "Diagnostic_procedure": "#c5b4e3",
          "Disease_disorder": "#c4b7ea",
          "Distance": "#bde0fe",
          "Dosage": "#b9e8d8",
          "Duration": "#ffdfba",
          "Family_history": "#e6ccb2",
          "Frequency": "#e9d8a6",
          "Height": "#f2eecb",
          "History": "#e2f0cb",
          "Lab_value": "#f4b3c2",
          "Mass": "#f4c4c3",
          "Medication": "#f9d5e5",
          "Nonbiological_location": "#f7a399",
          "Occupation": "#f6c3d0",
          "Other_entity": "#d5f5e3",
          "Other_event": "#9ddfd3",
          "Outcome": "#77c5d5",
          "Personal_background": "#a0ced9",
          "Qualitative_concept": "#e3b5a4",
          "Quantitative_concept": "#f1f0d2",
          "Severity": "#ffb347",
          "Sex": "#c5b4e3",
          "Shape": "#c4b7ea",
          "Sign_symptom": "#bde0fe",
          "Subject": "#b9e8d8",
          "Texture": "#ffdfba",
          "Therapeutic_procedure": "#e6ccb2",
          "Time": "#e9d8a6",
          "Volume": "#f2eecb",
          "Weight": "#e2f0cb"}

# %%
# Load the small English model
nlp = spacy.load("en_core_web_sm", disable=['ner'])

for doc_id, doc in data.items():
    text = doc['text']
    annotations = doc['annotations']


    # Create a Doc object from the text
    doc = nlp(text)
    prev_end = -1
    # Add your custom annotations to the Doc object
    for ann in annotations:
        label = ann["label"]
        start = ann["start"]
        end = ann["end"]
        if start > prev_end:
            span = doc.char_span(start, end, label=label)
            if span is not None:
                doc.ents += tuple([span])
        prev_end = end


    options = {"compact": True, "bg": "#F8F8F8",
           "ents": list(colors.keys()),
           "colors": colors}

    # Generate the HTML visualization
    html = displacy.render(doc, style="ent", options=options)
    break
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">CASE: A
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     28
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
# -
# <mark class="entity" style="background: #f6c3d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Age</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     previously
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #e2f0cb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     healthy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">History</span>
# </mark>
#
# <mark class="entity" style="background: #c5b4e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sex</span>
# </mark>
#
# <mark class="entity" style="background: #77c5d5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     presented
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Clinical_event</span>
# </mark>
#  with a
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
# -
# <mark class="entity" style="background: #ffdfba; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Duration</span>
# </mark>
#  history of
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palpitations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
# .<br>The
# <mark class="entity" style="background: #e3b5a4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     symptoms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Coreference</span>
# </mark>
#  occurred during
# <mark class="entity" style="background: #77c5d5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Clinical_event</span>
# </mark>
# , 2–3
# <mark class="entity" style="background: #e9d8a6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Frequency</span>
# </mark>
#
# <mark class="entity" style="background: #e9d8a6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     per
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Frequency</span>
# </mark>
#
# <mark class="entity" style="background: #e9d8a6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Frequency</span>
# </mark>
# , lasted
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     to
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Detailed_description</span>
# </mark>
#  and were associated with
# <mark class="entity" style="background: #bde0fe; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dyspnea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Sign_symptom</span>
# </mark>
# .<br>Except for a
# <mark class="entity" style="background: #f4b3c2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     grade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Lab_value</span>
# </mark>
#
# <mark class="entity" style="background: #f4b3c2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2/6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Lab_value</span>
# </mark>
#
# <mark class="entity" style="background: #ffb347; padding: 0.45em 0.6em; margin: 0 0.25em; line-hei

# %%
def create_html_doc_visualziation(html_file_dir="html_files"):

    if os.path.exists(html_file_dir):
        # Delete the contents of the directory
        shutil.rmtree(html_file_dir)
    # Recreate the directory
    os.makedirs(html_file_dir)

    # Load the small English model
    nlp = spacy.load("en_core_web_sm", disable=['ner'])

    # Define the HTML template
    html_template = """
    <!DOCTYPE html>
    <html>
    <head>
        <meta charset="utf-8">
        <title>{doc_id} Visualization</title>
    </head>
    <body>
        <h1>{doc_id} Visualization</h1>
        <p><a href="main.html">Back to Main Page</a></p>
        {displacy_output}
    </body>
    </html>
    """

    for doc_id, doc in data.items():
        text = doc['text']
        annotations = doc['annotations']


        # Create a Doc object from the text
        doc = nlp(text)
        prev_end = -1
        # Add your custom annotations to the Doc object
        for ann in annotations:
            label = ann["label"]
            start = ann["start"]
            end = ann["end"]
            if start > prev_end:
                span = doc.char_span(start, end, label=label)
                if span is not None:
                    doc.ents += tuple([span])
            prev_end = end


        options = {"compact": True, "bg": "#F8F8F8",
               "ents": list(colors.keys()),
               "colors": colors,
                "collapse_punct": False}

        # Generate the HTML visualization
        html = displacy.render(doc, style="ent", options=options, jupyter=False)

        # Fill in the HTML template with the doc ID and displaCy output
        html = html_template.format(doc_id=doc_id, displacy_output=html)

        # Write the HTML to a file
        with open(os.path.join(html_file_dir, f"{doc_id}.html"), "w", encoding="utf-8") as f:
            f.write(html)


    # Define the HTML template for the main page
    html_template = """
    <!DOCTYPE html>
    <html>
    <head>
        <meta charset="utf-8">
        <title>NER Document Visualization</title>
        <style>
            /* Add some basic styling */
            body {{
                font-family: Arial, sans-serif;
            }}
            h1 {{
                text-align: center;
            }}
            ul {{
                list-style: none;
                padding: 0;
            }}
            li {{
                margin-bottom: 10px;
            }}
            a {{
                text-decoration: none;
                color: blue;
            }}
        </style>
    </head>
    <body>
        <h1>Main Page</h1>
        <ul>
            {doc_links}
        </ul>
    </body>
    </html>
    """

    # Create a list of links to the doc files
    doc_links = ""
    for doc_id in doc_ids:
        doc_link = f'<li><a href="{doc_id}.html">{doc_id}</a></li>'
        doc_links += doc_link

    # Fill in the HTML template with the doc links
    html = html_template.format(doc_links=doc_links)

    # Write the HTML to a file
    with open(os.path.join(html_file_dir, "main.html"), "w", encoding="utf-8") as f:
        f.write(html)

# %%
create_html_doc_visualziation(html_file_dir="html_files")

# %% [markdown]
# ### Token frequency analysis

# %%
# Define the function to get token counts
def get_token_counts(data, remove_stop_words=True):
    token_counts = Counter()
    stop_words = set(stopwords.words('english'))
    for file_id, file_data in data.items():
        text = file_data['text']
        annotations = file_data['annotations']
        for annotation in annotations:
            label = annotation['label']
            start = annotation['start']
            end = annotation['end']
            annotated_text = text[start:end]
            annotated_tokens = annotated_text.split()
            if remove_stop_words:
                annotated_tokens = [token for token in annotated_tokens if token.lower() not in stop_words]
            token_counts.update(annotated_tokens)
    return token_counts

# %% [markdown]
# ### Annotated token frequency (without removing stop_words)

# %%
token_counts = get_token_counts(data, remove_stop_words=False)

# Sort the tokens by frequency
sorted_tokens = sorted(token_counts.items(), key=lambda x: x[1], reverse=True)

# Get the top 20 most common tokens and their counts
top_tokens = [t[0] for t in sorted_tokens[:20]]
top_counts = [t[1] for t in sorted_tokens[:20]]

# Create the bar plot
plt.bar(top_tokens, top_counts)
plt.xticks(rotation=90)
plt.xlabel('Token')
plt.ylabel('Frequency')
plt.title('Token Frequency Analysis')
plt.show()

# %% [markdown]
# ### Annotated token frequency (After removing stop_words)

# %%
token_counts = get_token_counts(data)

# Sort the tokens by frequency
sorted_tokens = sorted(token_counts.items(), key=lambda x: x[1], reverse=True)

# Get the top 20 most common tokens and their counts
top_tokens = [t[0] for t in sorted_tokens[:20]]
top_counts = [t[1] for t in sorted_tokens[:20]]

# Create the bar plot
plt.bar(top_tokens, top_counts)
plt.xticks(rotation=90)
plt.xlabel('Token')
plt.ylabel('Frequency')
plt.title('Token Frequency Analysis')
plt.show()

# %% [markdown]
# ### Collocation analysis

# %%
import nltk
from nltk.collocations import BigramAssocMeasures, BigramCollocationFinder

# Define the function to get collocations
def get_collocations(data):
    # Tokenize the text and filter out stop words
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokenized_text = [word.lower() for file_id, file_data in data.items() for word in file_data['text'].split() if word.lower() not in stop_words]

    # Create a bigram collocation finder
    bigram_measures = BigramAssocMeasures()
    bigram_finder = BigramCollocationFinder.from_words(tokenized_text)

    # Filter out low frequency bigrams and get the top 10 collocations
    bigram_finder.apply_freq_filter(5)
    top_collocations = bigram_finder.nbest(bigram_measures.pmi, 10)

    return top_collocations
get_collocations(data)
# Out:
# [('ground', 'glass'),
#  ('glasgow', 'coma'),
#  ('lesser', 'curvature'),
#  ('egfr', 'tki'),
#  ('vena', 'cava'),
#  ('bronchoalveolar', 'lavage'),
#  ('glomerular', 'filtration'),
#  ('muscularis', 'propria'),
#  ('6-minute', 'walk'),
#  ('alkaline', 'phosphatase')]

# %%
from nltk.collocations import BigramAssocMeasures, BigramCollocationFinder

def get_collocations(data):
    collocations = []
    for file_id, file_data in data.items():
        text = file_data['text']
        annotations = file_data['annotations']
        annotated_tokens = []
        for annotation in annotations:
            start = annotation['start']
            end = annotation['end']
            annotated_text = text[start:end]
            annotated_tokens += annotated_text.split()

        finder = BigramCollocationFinder.from_words(annotated_tokens)
        bigram_measures = BigramAssocMeasures()
        scored = finder.score_ngrams(bigram_measures.raw_freq)
        collocations += scored

    return collocations
get_collocations(data)
# Out:
# [(('right', 'ventricle'), 0.023255813953488372),
#  (('accessory', 'pathway'), 0.015503875968992248),
#  (('atrialized', 'right'), 0.015503875968992248),
#  (('tricuspid', 'valve'), 0.015503875968992248),
#  (('2', '3'), 0.007751937984496124),
#  (('2/6', 'holosystolic'), 0.007751937984496124),
#  (('28', 'year'), 0.007751937984496124),
#  (('3', 'times'), 0.007751937984496124),
#  (('30', 'minutes'), 0.007751937984496124),
#  (('6', 'months'), 0.007751937984496124),
#  (('6', 'week'), 0.007751937984496124),
#  (('Contrast', 'echocardiography'), 0.007751937984496124),
#  (('ECG', 'normal'), 0.007751937984496124),
#  (('ECG', 'prolonged'), 0.007751937984496124),
#  (("Ebstein's", 'anomaly'), 0.007751937984496124),
#  (('III,', 'aVF'), 0.007751937984496124),
#  (('PR', 'interval'), 0.007751937984496124),
#  (('Parkinson', 'White'), 0.007751937984496124),
#  (('QRS', 'complex'), 0.007751937984496124),
#  (('Transthoracic', 'echocardiography'), 0.007751937984496124),
#  (('V2', 'V4'), 0.007751937984496124),
#  (('V4', 'abnormal'), 0.007751937984496124),
#  (('White', 'pre'), 0.007751937984496124),
#  (('Wolff', 'Parkinson'), 0.007751937984496124),
#  (('a', 'time'), 0.007751937984496124),
#  (('aVF', 'and'), 0.007751937984496124),
#  (('ablation', 'ablation'), 0.007751937984496124),
#  (('ablation', 'catheter'), 0.007751937984496124),
#  (('abnormal', 'impulse'), 0.007751937984496124),
#  (('accentuation', 'physical'), 0.007751937984496124),
#  (('and', 'V2'), 0.007751937984496124),
#  (('anomaly', 'tricuspid'), 0.007751937984496124),
#  (('anterior', 'tricuspid'), 0.007751937984496124),
#  (('apical', 'displacement'), 0.007751937984496124),
#  (('at', 'a'), 0.007751937984496124),
#  (('atrium', 'electrophysiologic'), 0.007751937984496124),
#  (('atrium', 'inlet'), 0.007751937984496124),
#  (('border', 'inspiratory'), 0.007751937984496124),
#  (('bubbles', 'left'), 0.007751937984496124),
#  (('catheter', 'ECG'), 0.007751937984496124),
#  (('complex', 'leads'), 0.007751937984496124),
#  (('conduction', 'atrialized'), 0.007751937984496124),
#  (('displacement', 'valve'), 0.007751937984496124),
#  (('dyspnea', 'grade'), 0.007751937984496124),
#  (('echocardiography', "Ebstein's"), 0.007751937984496124),
#  (('echocardiography', 'using'), 0.007751937984496124),
#  (('electrocardiogram', 'ECG'), 0.007751937984496124),
#  (('electrophysiologic', 'study'), 0.007751937984496124),
#  (('elongated', 'septal'), 0.007751937984496124),
#  (('examination', 'unremarkable'), 0.007751937984496124),
#  (('excitation', 'pattern'), 0.007751937984496124),
#  (('follow', 'up'), 0.007751937984496124),
#  (('foramen', 'ovale'), 0.007751937984496124),
#  (('grade', '2/6'), 0.007751937984496124),
#  (('healthy', 'healthy'), 0.007751937984496124),
#  (('healthy', 'man'), 0.007751937984496124),
#  (('holosystolic', 'tricuspid'), 0.007751937984496124),
#  (('impulse', 'conduction'), 0.007751937984496124),
#  (('inlet', 'right'), 0.007751937984496124),
#  (('inspiratory', 'accentuation'), 0.007751937984496124),
#  (('interval', 'odd'), 0.007751937984496124),
#  (('leads', 'III,'), 0.007751937984496124),
#  (('leaflet', 'elongated'), 0.007751937984496124),
#  (('leaflet', 'rudimentary'), 0.007751937984496124),
#  (('left', 'atrium'), 0.007751937984496124),
#  (('left', 'shunting'), 0.007751937984496124),
#  (('left', 'sternal'), 0.007751937984496124),
#  (('man', 'presented'), 0.007751937984496124),
#  (('mapping', 'accessory'), 0.007751937984496124),
#  (('minutes', 'at'), 0.007751937984496124),
#  (('months', 'after'), 0.007751937984496124),
#  (('murmur', 'left'), 0.007751937984496124),
#  (('normal', 'sinus'), 0.007751937984496124),
#  (('odd', '“second”'), 0.007751937984496124),
#  (('old', 'previously'), 0.007751937984496124),
#  (('ovale', 'right'), 0.007751937984496124),
#  (('palpitations', 'follow'), 0.007751937984496124),
#  (('palpitations', 'symptoms'), 0.007751937984496124),
#  (('patent', 'foramen'), 0.007751937984496124),
#  (('pathway', 'Transthoracic'), 0.007751937984496124),
#  (('pathway', 'radiofrequency'), 0.007751937984496124),
#  (('pattern', 'right'), 0.007751937984496124),
#  (('per', 'week'), 0.007751937984496124),
#  (('physical', 'examination'), 0.007751937984496124),
#  (('pre', 'excitation'), 0.007751937984496124),
#  (('presented', '6'), 0.007751937984496124),
#  (('previously', 'healthy'), 0.007751937984496124),
#  (('prolonged', 'PR'), 0.007751937984496124),
#  (('radiofrequency', 'ablation'), 0.007751937984496124),
#  (('regurgitation', 'murmur'), 0.007751937984496124),
#  (('rest', '2'), 0.007751937984496124),
#  (('rhythm', 'Wolff'), 0.007751937984496124),
#  (('right', 'atrium'), 0.007751937984496124),
#  (('right', 'sided'), 0.007751937984496124),
#  (('right', 'to'), 0.007751937984496124),
#  (('rudimentary', 'Contrast'), 0.007751937984496124),
#  (('saline', 'patent'), 0.007751937984496124),
#  (('septal', 'leaflet'), 0.007751937984496124),
#  (('shunting', 'bubbles'), 0.007751937984496124),
#  (('sided', 'accessory'), 0.007751937984496124),
#  (('sinus', 'rhythm'), 0.007751937984496124),
#  (('sternal', 'border'), 0.007751937984496124),
#  (('study', 'mapping'), 0.007751937984496124),
#  (('symptoms', 'rest'), 0.007751937984496124),
#  (('time', 'dyspnea'), 0.007751937984496124),
#  (('times', 'per'), 0.007751937984496124),
#  (('to', '30'), 0.007751937984496124),
#  (('to', 'left'), 0.007751937984496124),
#  (('tricuspid', 'regurgitation'), 0.007751937984496124),
#  (('unremarkable', 'electrocardiogram'), 0.007751937984496124),
#  (('up', '6'), 0.007751937984496124),
#  (('up', 'to'), 0.007751937984496124),
#  (('using', 'saline'), 0.007751937984496124),
#  (('valve', 'apical'), 0.007751937984496124),
#  (('valve', 'atrialized'), 0.007751937984496124),
#  (('valve', 'leaflet'), 0.007751937984496124),
#  (('ventricle', 'anterior'), 0.007751937984496124),
#  (('ventricle', 'palpitations'), 0.007751937984496124),
#  (('ventricle', 'right'), 0.007751937984496124),
#  (('week', 'palpitations'), 0.007751937984496124),
#  (('week', 'up'), 0.007751937984496124),
#  (('year', 'old'), 0.007751937984496124),
#  (('“second”', 'QRS'), 0.007751937984496124),
#  (('tumor', 'cells'), 0.03255813953488372),
#  (('100', 'protein'), 0.009302325581395349),
#  (('4', 'cm'), 0.009302325581395349),
#  (('LCH', 'tumor'), 0.009302325581395349),
#  (('S', '100'), 0.009302325581395349),
#  (('around', 'the'), 0.009302325581395349),
#  (('both', 'lungs'), 0.009302325581395349),
#  (('cm', 'sized'), 0.009302325581395349),
#  (('cytologic', 'features'), 0.009302325581395349),
#  (('multiple', 'tiny'), 0.009302325581395349),
#  (('nodules', 'both'), 0.009302325581395349),
#  (('positive', 'S'), 0.009302325581395349),
#  (('protein', 'vimentin'), 0.009302325581395349),
#  (('strongly', 'positive'), 0.009302325581395349),
#  (('tiny', 'nodules'), 0.009302325581395349),
#  (('typical', 'LCH'), 0.009302325581395349),
#  (('(CT)', 'multiple'), 0.004651162790697674),
#  (('10', 'high'), 0.004651162790697674),
#  (('30', 'to'), 0.004651162790697674),
#  (('34', 'yr'), 0.004651162790697674),
#  (('60', 'per'), 0.004651162790697674),
#  (('Birbeck', 'granules'), 0.004651162790697674),
#  (('CD1a', 'infiltrations'), 0.004651162790697674),
#  (('CD1a', 'negative'), 0.004651162790697674),
#  (('CD20', 'HMB45'), 0.004651162790697674),
#  (('CD3', 'CD20'), 0.004651162790697674),
#  (('CD68', 'CD1a'), 0.004651162790697674),
#  (('CD68', 'focally'), 0.004651162790697674),
#  (('CT', 'scan'), 0.004651162790697674),
#  (('HMB45', 'ultrastructural'), 0.004651162790697674),
#  (('Immunohistochemically', 'strongly'), 0.004651162790697674),
#  (('LCH', 'around'), 0.004651162790697674),
#  (('Microscopically', 'tumor'), 0.004651162790697674),
#  (('a', 'sarcoma'), 0.004651162790697674),
#  (('a', 'typical'), 0.004651162790697674),
#  (('abnormal', 'few'), 0.004651162790697674),
#  (('after', 'lobectomy'), 0.004651162790697674),
#  (('aggregated', 'in'), 0.004651162790697674),
#  (('aggregations', 'around'), 0.004651162790697674),
#  (('analysis', 'failed'), 0.004651162790697674),
#  (('and', 'cured'), 0.004651162790697674),
#  (('antigen', 'CD3'), 0.004651162790697674),
#  (('any', 'Birbeck'), 0.004651162790697674),
#  (('be', 'involved'), 0.004651162790697674),
#  (('biopsy', 'possibility'), 0.004651162790697674),
#  (('biopsy', 'right'), 0.004651162790697674),
#  (('bronchioles', 'tumor'), 0.004651162790697674),
#  (('cells', 'aggregated'), 0.004651162790697674),
#  (('cells', 'cytologic'), 0.004651162790697674),
#  (('cells', 'five'), 0.004651162790697674),
#  (('cells', 'numerous'), 0.004651162790697674),
#  (('cells', 'radiologic'), 0.004651162790697674),
#  (('cells', 'similar'), 0.004651162790697674),
#  (('cells', 'strongly'), 0.004651162790697674),
#  (('cells', 'vesicular'), 0.004651162790697674),
#  (('change', 'in'), 0.004651162790697674),
#  (('chronic', 'cough'), 0.004651162790697674),
#  (('circumscribed', 'lobulated'), 0.004651162790697674),
#  (('computed', 'tomographic'), 0.004651162790697674),
#  (('cough', 'smoker'), 0.004651162790697674),
#  (('cured', 'computed'), 0.004651162790697674),
#  (('cytokeratin', 'epithelial'), 0.004651162790697674),
#  (('cytoplasm', 'tumor'), 0.004651162790697674),
#  (('demonstrate', 'any'), 0.004651162790697674),
#  (('doing', 'well'), 0.004651162790697674),
#  (('eosinophils', 'tumor'), 0.004651162790697674),
#  (('epithelial', 'membrane'), 0.004651162790697674),
#  (('examination', 'LCH'), 0.004651162790697674),
#  (('examinations', 'no'), 0.004651162790697674),
#  (('failed', 'to'), 0.004651162790697674),
#  (('features', 'pleomorphic/hyperchromatic'), 0.004651162790697674),
#  (('features', 'tumor'), 0.004651162790697674),
#  (('fever', 'chronic'), 0.004651162790697674),
#  (('few', 'foci'), 0.004651162790697674),
#  (('fields', 'some'), 0.004651162790697674),
#  (('figures', '30'), 0.004651162790697674),
#  (('five', 'months'), 0.004651162790697674),
#  (('focally', 'positive'), 0.004651162790697674),
#  (('foci', 'typical'), 0.004651162790697674),
#  (('following', 'one'), 0.004651162790697674),
#  (('for', 'the'), 0.004651162790697674),
#  (('giant', 'cells'), 0.004651162790697674),
#  (('granules', 'cytoplasm'), 0.004651162790697674),
#  (('gray', 'white'), 0.004651162790697674),
#  (('grooved', 'nuclei'), 0.004651162790697674),
#  (('growth', 'cytologic'), 0.004651162790697674),
#  (('high', 'power'), 0.004651162790697674),
#  (('history', 'of'), 0.004651162790697674),
#  (('in', 'a'), 0.004651162790697674),
#  (('in', 'large'), 0.004651162790697674),
#  (('in', 'the'), 0.004651162790697674),
#  (('infiltrations', 'lymphocytes'), 0.004651162790697674),
#  (('infiltrative', 'growth'), 0.004651162790697674),
#  (('involved', 'quit'), 0.004651162790697674),
#  (('large', 'sheets'), 0.004651162790697674),
#  (('left', 'lower'), 0.004651162790697674),
#  (('lobe', 'microscopic'), 0.004651162790697674),
#  (('lobe', 'multiple'), 0.004651162790697674),
#  (('lobectomy', '4'), 0.004651162790697674),
#  (('lobectomy', 'doing'), 0.004651162790697674),
#  (('lobulated', 'gray'), 0.004651162790697674),
#  (('lower', 'lobe'), 0.004651162790697674),
#  (('lung', 'biopsy'), 0.004651162790697674),
#  (('lungs', 'needle'), 0.004651162790697674),
#  (('lungs', 'thoracoscopic'), 0.004651162790697674),
#  (('lymphocytes', 'eosinophils'), 0.004651162790697674),
#  (('main', 'mass'), 0.004651162790697674),
#  (('main', 'tumor'), 0.004651162790697674),
#  (('man', 'presented'), 0.004651162790697674),
#  (('mass', 'Immunohistochemically'), 0.004651162790697674),
#  (('mass', 'Microscopically'), 0.004651162790697674),
#  (('mass', 'left'), 0.004651162790697674),
#  (('mass', 'small'), 0.004651162790697674),
#  (('membrane', 'antigen'), 0.004651162790697674),
#  (('microscopic', 'examination'), 0.004651162790697674),
#  (('mitotic', 'figures'), 0.004651162790697674),
#  (('months', 'after'), 0.004651162790697674),
#  (('multinucleated', 'tumor'), 0.004651162790697674),
#  (('needle', 'biopsy'), 0.004651162790697674),
#  (('negative', 'cytokeratin'), 0.004651162790697674),
#  (('no', 'other'), 0.004651162790697674),
#  (('no', 'significant'), 0.004651162790697674),
#  (('nodules', 'main'), 0.004651162790697674),
#  (('nuclei', 'prominent'), 0.004651162790697674),
#  (('nuclei', 'small'), 0.004651162790697674),
#  (('nucleoli', 'multinucleated'), 0.004651162790697674),
#  (('numerous', 'mitotic'), 0.004651162790697674),
#  (('of', 'a'), 0.004651162790697674),
#  (('of', 'pulmonary'), 0.004651162790697674),
#  (('of', 'them'), 0.004651162790697674),
#  (('old', 'man'), 0.004651162790697674),
#  (('one', 'year'), 0.004651162790697674),
#  (('organs', 'were'), 0.004651162790697674),
#  (('other', 'organs'), 0.004651162790697674),
#  (('per', '10'), 0.004651162790697674),
#  (('pleomorphic/hyperchromatic', 'nuclei'), 0.004651162790697674),
#  (('poorly', 'circumscribed'), 0.004651162790697674),
#  (('positive', 'CD1a'), 0.004651162790697674),
#  (('positive', 'CD68'), 0.004651162790697674),
#  (('possibility', 'of'), 0.004651162790697674),
#  (('power', 'fields'), 0.004651162790697674),
#  (('presented', 'fever'), 0.004651162790697674),
#  (('prominent', 'nucleoli'), 0.004651162790697674),
#  (('pulmonary', 'pulmonary'), 0.004651162790697674),
#  (('pulmonary', 'tuberculosis'), 0.004651162790697674),
#  (('quit', 'smoking'), 0.004651162790697674),
#  (('radiologic', 'examinations'), 0.004651162790697674),
#  (('radiologic', 'findings'), 0.004651162790697674),
#  (('right', 'upper'), 0.004651162790697674),
#  (('sarcoma', 'lobectomy'), 0.004651162790697674),
#  (('satellite', 'nodules'), 0.004651162790697674),
#  (('scan', '4'), 0.004651162790697674),
#  (('seen', 'in'), 0.004651162790697674),
#  (('sheets', 'infiltrative'), 0.004651162790697674),
#  (('significant', 'change'), 0.004651162790697674),
#  (('similar', 'to'), 0.004651162790697674),
#  (('sized', 'mass'), 0.004651162790697674),
#  (('sized', 'poorly'), 0.004651162790697674),
#  (('small', 'aggregations'), 0.004651162790697674),
#  (('small', 'satellite'), 0.004651162790697674),
#  (('smoker', 'history'), 0.004651162790697674),
#  (('smoking', 'well'), 0.004651162790697674),
#  (('some', 'of'), 0.004651162790697674),
#  (('the', 'bronchioles'), 0.004651162790697674),
#  (('the', 'following'), 0.004651162790697674),
#  (('the', 'main'), 0.004651162790697674),
#  (('the', 'radiologic'), 0.004651162790697674),
#  (('them', 'were'), 0.004651162790697674),
#  (('thoracoscopic', 'lung'), 0.004651162790697674),
#  (('those', 'seen'), 0.004651162790697674),
#  (('thought', 'to'), 0.004651162790697674),
#  (('to', '60'), 0.004651162790697674),
#  (('to', 'be'), 0.004651162790697674),
#  (('to', 'demonstrate'), 0.004651162790697674),
#  (('to', 'those'), 0.004651162790697674),
#  (('tomographic', '(CT)'), 0.004651162790697674),
#  (('treated', 'and'), 0.004651162790697674),
#  (('tuberculosis', 'treated'), 0.004651162790697674),
#  (('tuberculosis', 'tuberculosis'), 0.004651162790697674),
#  (('tumor', 'giant'), 0.004651162790697674),
#  (('tumor', 'mass'), 0.004651162790697674),
#  (('ultrastructural', 'analysis'), 0.004651162790697674),
#  (('upper', 'lobe'), 0.004651162790697674),
#  (('vesicular', 'grooved'), 0.004651162790697674),
#  (('vimentin', 'CD68'), 0.004651162790697674),
#  (('vimentin', 'positive'), 0.004651162790697674),
#  (('well', 'for'), 0.004651162790697674),
#  (('well', 'no'), 0.004651162790697674),
#  (('were', 'abnormal'), 0.004651162790697674),
#  (('were', 'thought'), 0.004651162790697674),
#  (('white', 'mass'), 0.004651162790697674),
#  (('year', 'CT'), 0.004651162790697674),
#  (('yr', 'old'), 0.004651162790697674),
#  (('a', 'year'), 0.008264462809917356),
#  (('abdominal', 'pain'), 0.008264462809917356),
#  (('ankles', 'feet'), 0.008264462809917356),
#  (('cutaneous', 'fistula'), 0.008264462809917356),
#  (('elbows', 'ankles'), 0.008264462809917356),
#  (('history', 'of'), 0.008264462809917356),
#  (('over', 'the'), 0.008264462809917356),
#  (('×', '109/L'), 0.008264462809917356),
#  (('109/L', 'C'), 0.004132231404958678),
#  (('109/L', 'platelets'), 0.004132231404958678),
#  (('125/minute', 'cardio'), 0.004132231404958678),
#  (('13.1', 'gm/dl'), 0.004132231404958678),
#  (('15.8', '×'), 0.004132231404958678),
#  (('2', 'years'), 0.004132231404958678),
#  (('23', 'year'), 0.004132231404958678),
#  (('3', 'years'), 0.004132231404958678),
#  (('37.7', 'mg/L'), 0.004132231404958678),
#  (('4', '4'), 0.004132231404958678),
#  (('4', 'months'), 0.004132231404958678),
#  (('4', 'year'), 0.004132231404958678),
#  (('585', '×'), 0.004132231404958678),
#  (('60', 'mg'), 0.004132231404958678),
#  (('69', 'mm/hr'), 0.004132231404958678),
#  (('B', 'and'), 0.004132231404958678),
#  (('C', 'reactive'), 0.004132231404958678),
#  (('C', 'serology'), 0.004132231404958678),
#  (("Crohn's", "Crohn's"), 0.004132231404958678),
#  (("Crohn's", 'disease'), 0.004132231404958678),
#  (('Examination', 'of'), 0.004132231404958678),
#  (('Hepatitis', 'B'), 0.004132231404958678),
#  (('Infliximab', 'a'), 0.004132231404958678),
#  (('One', 'month'), 0.004132231404958678),
#  (('Pentasa', '4'), 0.004132231404958678),
#  (('Rheumatoid', 'factor'), 0.004132231404958678),
#  (('The', 'buttocks'), 0.004132231404958678),
#  (('Transthoracic', 'echocardiogram'), 0.004132231404958678),
#  (('Urea', 'electrolytes'), 0.004132231404958678),
#  (('abdomen', 'minimally'), 0.004132231404958678),
#  (('admission', 'hospital'), 0.004132231404958678),
#  (('afebrile', 'resting'), 0.004132231404958678),
#  (('all', 'features'), 0.004132231404958678),
#  (('analysis', 'microscopy'), 0.004132231404958678),
#  (('and', 'C'), 0.004132231404958678),
#  (('ankles', 'laboratory'), 0.004132231404958678),
#  (('ankles', 'rash'), 0.004132231404958678),
#  (('antibodies', 'cryoglobulins'), 0.004132231404958678),
#  (('antineutrophil', 'cytoplasmic'), 0.004132231404958678),
#  (('antinuclear', 'antineutrophil'), 0.004132231404958678),
#  (('any', 'recurrence'), 0.004132231404958678),
#  (('at', 'least'), 0.004132231404958678),
#  (('azathioprine', 'corticosteroiods'), 0.004132231404958678),
#  (('been', 'present'), 0.004132231404958678),
#  (('biopsy', 'perivascular'), 0.004132231404958678),
#  (('blind', 'tracts'), 0.004132231404958678),
#  (('blood', 'count'), 0.004132231404958678),
#  (('blood', 'cultures'), 0.004132231404958678),
#  (('both', 'ankles'), 0.004132231404958678),
#  (('bowel', 'disease'), 0.004132231404958678),
#  (('buttocks', 'were'), 0.004132231404958678),
#  (('cardio', 'respiratory'), 0.004132231404958678),
#  (('complement', 'urine'), 0.004132231404958678),
#  (('complete', 'resolution'), 0.004132231404958678),
#  (('complex', 'ileo'), 0.004132231404958678),
#  (('corticosteroiods', 'three'), 0.004132231404958678),
#  (('count', '15.8'), 0.004132231404958678),
#  (('course', 'of'), 0.004132231404958678),
#  (('crusting', 'no'), 0.004132231404958678),
#  (('crusts', 'elbows'), 0.004132231404958678),
#  (('cryoglobulins', 'Hepatitis'), 0.004132231404958678),
#  (('cultures', 'sterile'), 0.004132231404958678),
#  (('cytoplasmic', 'antibodies'), 0.004132231404958678),
#  (('day', 'malaise'), 0.004132231404958678),
#  (('day', 'prompt'), 0.004132231404958678),
#  (('defunctioning', 'ileostomy'), 0.004132231404958678),
#  (('diarrhoea', 'joint'), 0.004132231404958678),
#  (('disease', 'azathioprine'), 0.004132231404958678),
#  (('disease', 'disease'), 0.004132231404958678),
#  (('disease', 'presented'), 0.004132231404958678),
#  (('duration', 'bowel'), 0.004132231404958678),
#  (('earlier', 'One'), 0.004132231404958678),
#  (('earlier', 'defunctioning'), 0.004132231404958678),
#  (('earlier', 'laparotomy'), 0.004132231404958678),
#  (('earlier', 'no'), 0.004132231404958678),
#  (('echocardiogram', 'no'), 0.004132231404958678),
#  (('elbows', 'wrists'), 0.004132231404958678),
#  (('electrolytes', 'complement'), 0.004132231404958678),
#  (('endocarditis', 'multiple'), 0.004132231404958678),
#  (('erythematous', 'macules'), 0.004132231404958678),
#  (('erythrocyte', 'sedimentation'), 0.004132231404958678),
#  (('examination', 'normal'), 0.004132231404958678),
#  (('exposure', 'infection'), 0.004132231404958678),
#  (('extra', 'intestinal'), 0.004132231404958678),
#  (('factor', 'antinuclear'), 0.004132231404958678),
#  (('features', 'prednisolone'), 0.004132231404958678),
#  (('feet', 'The'), 0.004132231404958678),
#  (('feet', 'erythematous'), 0.004132231404958678),
#  (('fever', 'abdominal'), 0.004132231404958678),
#  (('fibrinoid', 'necrosis'), 0.004132231404958678),
#  (('fistula', 'blind'), 0.004132231404958678),
#  (('fistula', 'had'), 0.004132231404958678),
#  (('fistula', 'of'), 0.004132231404958678),
#  (('following', '3'), 0.004132231404958678),
#  (('for', 'a'), 0.004132231404958678),
#  (('gm/dl', 'white'), 0.004132231404958678),
#  (('guarding', 'rebound'), 0.004132231404958678),
#  (('had', 'been'), 0.004132231404958678),
#  (('haemoglobin', '13.1'), 0.004132231404958678),
#  (('hospital', 'thin'), 0.004132231404958678),
#  (('ileal', 'stricture'), 0.004132231404958678),
#  (('ileo', 'cutaneous'), 0.004132231404958678),
#  (('ileo', 'rectal'), 0.004132231404958678),
#  (('ileostomy', 'persistent'), 0.004132231404958678),
#  (('ileostomy', 'without'), 0.004132231404958678),
#  (('infection', 'no'), 0.004132231404958678),
#  (('infiltrate', 'neutrophils'), 0.004132231404958678),
#  (('infusions', 'Infliximab'), 0.004132231404958678),
#  (('interphalangeal', 'metacarpophalangeal'), 0.004132231404958678),
#  (('intestinal', 'manifestations'), 0.004132231404958678),
#  (('joint', 'pains'), 0.004132231404958678),
#  (('joints', 'both'), 0.004132231404958678),
#  (('knees', 'ankles'), 0.004132231404958678),
#  (('laboratory', 'tests'), 0.004132231404958678),
#  (('laparotomy', 'complex'), 0.004132231404958678),
#  (('least', '2'), 0.004132231404958678),
#  (('lesions', 'crusting'), 0.004132231404958678),
#  (('leukocytoclastic', 'vasculitis'), 0.004132231404958678),
#  (('lymphohistiocytic', 'infiltrate'), 0.004132231404958678),
#  (('macules', 'vesico'), 0.004132231404958678),
#  (('malaise', 'fever'), 0.004132231404958678),
#  (('male', '4'), 0.004132231404958678),
#  (('manifestations', 'admission'), 0.004132231404958678),
#  (('medication', 'Pentasa'), 0.004132231404958678),
#  (('metacarpophalangeal', 'joints'), 0.004132231404958678),
#  (('metacarpophalangeals', 'knees'), 0.004132231404958678),
#  (('mg', 'prednisolone'), 0.004132231404958678),
#  (('mg/L', 'erythrocyte'), 0.004132231404958678),
#  (('microscopy', 'normal'), 0.004132231404958678),
#  (('minimally', 'tender'), 0.004132231404958678),
#  (('mm/hr', 'Urea'), 0.004132231404958678),
#  (('month', 'earlier'), 0.004132231404958678),
#  (('month', 'without'), 0.004132231404958678),
#  (('months', 'earlier'), 0.004132231404958678),
#  (('multiple', 'blood'), 0.004132231404958678),
#  (('necrosis', 'vessels'), 0.004132231404958678),
#  (('negative', 'Transthoracic'), 0.004132231404958678),
#  (('neutrophils', 'fibrinoid'), 0.004132231404958678),
#  (('no', 'extra'), 0.004132231404958678),
#  (('no', 'history'), 0.004132231404958678),
#  (('no', 'regular'), 0.004132231404958678),
#  (('no', 'signs'), 0.004132231404958678),
#  (('normal', 'Rheumatoid'), 0.004132231404958678),
#  (('normal', 'abdomen'), 0.004132231404958678),
#  (('of', "Crohn's"), 0.004132231404958678),
#  (('of', 'all'), 0.004132231404958678),
#  (('of', 'at'), 0.004132231404958678),
#  (('of', 'endocarditis'), 0.004132231404958678),
#  (('of', 'one'), 0.004132231404958678),
#  (('of', 'sexual'), 0.004132231404958678),
#  (('of', 'the'), 0.004132231404958678),
#  (('old', 'white'), 0.004132231404958678),
#  (('one', 'month'), 0.004132231404958678),
#  (('pain', 'cutaneous'), 0.004132231404958678),
#  (('pain', 'vomiting'), 0.004132231404958678),
#  (('pains', 'shoulders'), 0.004132231404958678),
#  (('per', 'day'), 0.004132231404958678),
#  (('perivascular', 'lymphohistiocytic'), 0.004132231404958678),
#  (('persistent', 'abdominal'), 0.004132231404958678),
#  (('platelets', '585'), 0.004132231404958678),
#  (('prednisolone', 'per'), 0.004132231404958678),
#  (('prednisolone', 'tapered'), 0.004132231404958678),
#  (('present', 'for'), 0.004132231404958678),
#  (('presented', 'two'), 0.004132231404958678),
#  (('prompt', 'complete'), 0.004132231404958678),
#  (('protein', '37.7'), 0.004132231404958678),
#  (('proximal', 'interphalangeal'), 0.004132231404958678),
#  (('pustular', 'lesions'), 0.004132231404958678),
#  (('pustules', 'crusts'), 0.004132231404958678),
#  (('rash', 'elbows'), 0.004132231404958678),
#  (('rate', '69'), 0.004132231404958678),
#  (('reactive', 'protein'), 0.004132231404958678),
#  (('rebound', 'tenderness'), 0.004132231404958678),
#  (('rectal', 'fistula'), 0.004132231404958678),
#  (('recurrence', 'over'), 0.004132231404958678),
#  (('regular', 'medication'), 0.004132231404958678),
#  (('resolution', 'of'), 0.004132231404958678),
#  (('respiratory', 'examination'), 0.004132231404958678),
#  (('resting', 'tachycardia'), 0.004132231404958678),
#  (('sedimentation', 'rate'), 0.004132231404958678),
#  (('serology', 'negative'), 0.004132231404958678),
#  (('sexual', 'exposure'), 0.004132231404958678),
#  (('shoulders', 'elbows'), 0.004132231404958678),
#  (('signs', 'of'), 0.004132231404958678),
#  (('skin', 'biopsy'), 0.004132231404958678),
#  (('skin', 'pustules'), 0.004132231404958678),
#  (('spared.', 'synovitis'), 0.004132231404958678),
#  (('sterile', 'skin'), 0.004132231404958678),
#  (('stomal', 'diarrhoea'), 0.004132231404958678),
#  (('stricture', 'ileo'), 0.004132231404958678),
#  (('synovitis', 'wrists'), 0.004132231404958678),
#  (('tachycardia', '125/minute'), 0.004132231404958678),
#  (('tapered', 'over'), 0.004132231404958678),
#  (('tender', 'ileostomy'), 0.004132231404958678),
#  (('tenderness', 'Examination'), 0.004132231404958678),
#  (('terminal', 'ileal'), 0.004132231404958678),
#  (('tests', 'haemoglobin'), 0.004132231404958678),
#  (('the', 'course'), 0.004132231404958678),
#  (('the', 'following'), 0.004132231404958678),
#  (('the', 'skin'), 0.004132231404958678),
#  (('thin', 'afebrile'), 0.004132231404958678),
#  (('three', 'infusions'), 0.004132231404958678),
#  (('tracts', 'two'), 0.004132231404958678),
#  (('two', 'day'), 0.004132231404958678),
#  (('two', 'weeks'), 0.004132231404958678),
#  (('urine', 'analysis'), 0.004132231404958678),
#  (('vasculitis', '60'), 0.004132231404958678),
#  (('vesico', 'pustular'), 0.004132231404958678),
#  (('vessels', 'leukocytoclastic'), 0.004132231404958678),
#  (('vomiting', 'stomal'), 0.004132231404958678),
#  (('weeks', 'earlier'), 0.004132231404958678),
#  (('were', 'spared.'), 0.004132231404958678),
#  (('white', 'blood'), 0.004132231404958678),
#  (('white', 'male'), 0.004132231404958678),
#  (('without', 'any'), 0.004132231404958678),
#  (('without', 'guarding'), 0.004132231404958678),
#  (('without', 'without'), 0.004132231404958678),
#  (('wrists', 'metacarpophalangeals'), 0.004132231404958678),
#  (('wrists', 'proximal'), 0.004132231404958678),
#  (('year', 'earlier'), 0.004132231404958678),
#  (('year', 'history'), 0.004132231404958678),
#  (('year', 'old'), 0.004132231404958678),
#  (('year', 'terminal'), 0.004132231404958678),
#  (('year', 'year'), 0.004132231404958678),
#  (('years', 'duration'), 0.004132231404958678),
#  (('throat', 'pack'), 0.014184397163120567),
#  (('0.15', 'μg/kg'), 0.0070921985815602835),
#  (('0.25', 'μg/kg/min'), 0.0070921985815602835),
#  (('0.5', 'μg/kg'), 0.0070921985815602835),
#  (('100', 'minutes'), 0.0070921985815602835),
#  (('2', 'mg/kg'), 0.0070921985815602835),
#  (('20', 'cm'), 0.0070921985815602835),
#  (('30', 'year'), 0.0070921985815602835),
#  (('7', 'mm'), 0.0070921985815602835),
#  (('90', 'mmHg'), 0.0070921985815602835),
#  (('Cisatracurium', '0.15'), 0.0070921985815602835),
#  (('Examination', 'deviation'), 0.0070921985815602835),
#  (('Full', 'Full'), 0.0070921985815602835),
#  (('Full', 'recovery'), 0.0070921985815602835),
#  (('General', 'anaesthesia'), 0.0070921985815602835),
#  (('H2O', 'adjustment'), 0.0070921985815602835),
#  (('MRN', 'central'), 0.0070921985815602835),
#  (('Macintosh', 'blade'), 0.0070921985815602835),
#  (('Moderate', 'arterial'), 0.0070921985815602835),
#  (('Muscle', 'paralysis'), 0.0070921985815602835),
#  (('N2O', 'throat'), 0.0070921985815602835),
#  (('No.3', '7'), 0.0070921985815602835),
#  (('Propofol', '2'), 0.0070921985815602835),
#  (('Remifentanyl', '0.5'), 0.0070921985815602835),
#  (('Remifentanyl', 'continuous'), 0.0070921985815602835),
#  (('Sevofluorane', 'in'), 0.0070921985815602835),
#  (('Transoral', 'intubation'), 0.0070921985815602835),
#  (('adjustment', 'of'), 0.0070921985815602835),
#  (('anaesthesia', 'Remifentanyl'), 0.0070921985815602835),
#  (('anaesthesia', 'Sevofluorane'), 0.0070921985815602835),
#  (('arterial', 'hypotension'), 0.0070921985815602835),
#  (('artery', 'pressure'), 0.0070921985815602835),
#  (('blade', 'No.3'), 0.0070921985815602835),
#  (('central', 'cranial'), 0.0070921985815602835),
#  (('cm', 'H2O'), 0.0070921985815602835),
#  (('continuous', 'infusion'), 0.0070921985815602835),
#  (('cord', 'paralysis'), 0.0070921985815602835),
#  (('corner', 'of'), 0.0070921985815602835),
#  (('cranial', 'nerve'), 0.0070921985815602835),
#  (('cuff', 'volume'), 0.0070921985815602835),
#  (('day', 'difficulty'), 0.0070921985815602835),
#  (('deviation', 'tongue'), 0.0070921985815602835),
#  (('diameter', 'reinforced'), 0.0070921985815602835),
#  (('difficulty', 'in'), 0.0070921985815602835),
#  (('dysphonia', 'hoarseness'), 0.0070921985815602835),
#  (('elevated', 'operation'), 0.0070921985815602835),
#  (('examination', 'magnetic'), 0.0070921985815602835),
#  (('extubated', 'throat'), 0.0070921985815602835),
#  (('female', 'rhinoplasty'), 0.0070921985815602835),
#  (('following', 'day'), 0.0070921985815602835),
#  (('forward', 'trunk'), 0.0070921985815602835),
#  (('four', 'months'), 0.0070921985815602835),
#  (('functions', 'within'), 0.0070921985815602835),
#  (('general', 'anaesthesia'), 0.0070921985815602835),
#  (('haematoma', 'movements'), 0.0070921985815602835),
#  (('head', 'slightly'), 0.0070921985815602835),
#  (('hoarseness', 'Examination'), 0.0070921985815602835),
#  (('hypoglossal', 'recurrent'), 0.0070921985815602835),
#  (('hypotension', 'systolic'), 0.0070921985815602835),
#  (('imaging', 'MRN'), 0.0070921985815602835),
#  (('in', 'oxygen/air'), 0.0070921985815602835),
#  (('in', 'swallowing'), 0.0070921985815602835),
#  (('inclined', 'forward'), 0.0070921985815602835),
#  (('infusion', '0.25'), 0.0070921985815602835),
#  (('injury', 'local'), 0.0070921985815602835),
#  (('intubation', 'Macintosh'), 0.0070921985815602835),
#  (('intubation', 'tube'), 0.0070921985815602835),
#  (('involvement', 'steroids'), 0.0070921985815602835),
#  (('laryngeal', 'functions'), 0.0070921985815602835),
#  (('laryngeal', 'nerve'), 0.0070921985815602835),
#  (('laryngoscopy', 'intubation'), 0.0070921985815602835),
#  (('lingual', 'laryngeal'), 0.0070921985815602835),
#  (('local', 'oedema'), 0.0070921985815602835),
#  (('magnetic', 'resonance'), 0.0070921985815602835),
#  (('mg/kg', 'Muscle'), 0.0070921985815602835),
#  (('minutes', 'extubated'), 0.0070921985815602835),
#  (('mm', 'diameter'), 0.0070921985815602835),
#  (('mmHg', 'semi'), 0.0070921985815602835),
#  (('months', 'after'), 0.0070921985815602835),
#  (('mouth', 'problems'), 0.0070921985815602835),
#  (('movements', 'pharynx'), 0.0070921985815602835),
#  (('nerve', 'injury'), 0.0070921985815602835),
#  (('nerve', 'involvement'), 0.0070921985815602835),
#  (('neurological', 'examination'), 0.0070921985815602835),
#  (('normal', 'neurological'), 0.0070921985815602835),
#  (('oedema', 'haematoma'), 0.0070921985815602835),
#  (('of', 'cuff'), 0.0070921985815602835),
#  (('of', 'the'), 0.0070921985815602835),
#  (('old', 'female'), 0.0070921985815602835),
#  (('operation', '100'), 0.0070921985815602835),
#  (('oxygen/air', 'Remifentanyl'), 0.0070921985815602835),
#  (('pack', 'pharynx'), 0.0070921985815602835),
#  (('pack', 'problems'), 0.0070921985815602835),
#  (('palate', 'normal'), 0.0070921985815602835),
#  (('paralysis', 'Cisatracurium'), 0.0070921985815602835),
#  (('paralysis', 'hypoglossal'), 0.0070921985815602835),
#  (('pharynx', 'General'), 0.0070921985815602835),
#  (('pharynx', 'soft'), 0.0070921985815602835),
#  (('position', 'head'), 0.0070921985815602835),
#  (('pressure', '90'), 0.0070921985815602835),
#  (('pressure', '≤'), 0.0070921985815602835),
#  (('problems', 'following'), 0.0070921985815602835),
#  (('problems', 'laryngoscopy'), 0.0070921985815602835),
#  (('recovery', 'lingual'), 0.0070921985815602835),
#  (('recovery', 'recovery'), 0.0070921985815602835),
#  (('recurrent', 'laryngeal'), 0.0070921985815602835),
#  (('reinforced', 'tracheal'), 0.0070921985815602835),
#  (('resonance', 'imaging'), 0.0070921985815602835),
#  (('rhinoplasty', 'general'), 0.0070921985815602835),
#  (('right', 'corner'), 0.0070921985815602835),
#  (('right', 'side'), 0.0070921985815602835),
#  (('semi', 'supine'), 0.0070921985815602835),
#  (('side', 'vocal'), 0.0070921985815602835),
#  (('slightly', 'elevated'), 0.0070921985815602835),
#  (('slightly', 'inclined'), 0.0070921985815602835),
#  (('soft', 'palate'), 0.0070921985815602835),
#  (('speech', 'swallowing'), 0.0070921985815602835),
#  (('steroids', 'vitamins'), 0.0070921985815602835),
#  (('supine', 'position'), 0.0070921985815602835),
#  (('swallowing', 'dysphonia'), 0.0070921985815602835),
#  (('swallowing', 'therapy'), 0.0070921985815602835),
#  (('systolic', 'artery'), 0.0070921985815602835),
#  (('the', 'mouth'), 0.0070921985815602835),
#  (('therapy', 'Full'), 0.0070921985815602835),
#  (('tongue', 'right'), 0.0070921985815602835),
#  (('trachea', 'right'), 0.0070921985815602835),
#  (('tracheal', 'tube'), 0.0070921985815602835),
#  (('trunk', 'slightly'), 0.0070921985815602835),
#  (('tube', 'pressure'), 0.0070921985815602835),
#  (('tube', 'trachea'), 0.0070921985815602835),
#  (('vitamins', 'speech'), 0.0070921985815602835),
#  (('vocal', 'cord'), 0.0070921985815602835),
#  (('volume', 'N2O'), 0.0070921985815602835),
#  (('within', 'four'), 0.0070921985815602835),
#  (('year', 'old'), 0.0070921985815602835),
#  (('μg/kg', 'Propofol'), 0.0070921985815602835),
#  (('μg/kg', 'Transoral'), 0.0070921985815602835),
#  (('μg/kg/min', 'Moderate'), 0.0070921985815602835),
#  (('≤', '20'), 0.0070921985815602835),
#  (('hospital', 'day'), 0.01652892561983471),
#  (('gram', 'positive'), 0.008264462809917356),
#  (('hearing', 'loss'), 0.008264462809917356),
#  (('leukocyte', 'count'), 0.008264462809917356),
#  (('negative', 'hospital'), 0.008264462809917356),
#  (('nuchal', 'rigidity'), 0.008264462809917356),
#  (('positive', 'cocci'), 0.008264462809917356),
#  (('(MIC', '='), 0.004132231404958678),
#  (('0.03),', 'ceftriaxone,'), 0.004132231404958678),
#  (('10', 'day'), 0.004132231404958678),
#  (('16,400/mm3', 'neutrophils'), 0.004132231404958678),
#  (('18%', 'lymphocytes'), 0.004132231404958678),
#  (('2', 'blood'), 0.004132231404958678),
#  (('2', 'butcher'), 0.004132231404958678),
#  (('20', 'Strep'), 0.004132231404958678),
#  (('2003', 'ill'), 0.004132231404958678),
#  (('21,000/mm3', '16,400/mm3'), 0.004132231404958678),
#  (('24', 'million'), 0.004132231404958678),
#  (('38.9°C', 'nuchal'), 0.004132231404958678),
#  (('487/μL', '80%'), 0.004132231404958678),
#  (('5', 'days'), 0.004132231404958678),
#  (('5', 'hearing'), 0.004132231404958678),
#  (('60', 'year'), 0.004132231404958678),
#  (('7', 'month'), 0.004132231404958678),
#  (('7', 'organism'), 0.004132231404958678),
#  (('70', 'dB'), 0.004132231404958678),
#  (('80%', 'polymorphonuclear'), 0.004132231404958678),
#  (('9', 'formal'), 0.004132231404958678),
#  (('<167', 'mg/dL'), 0.004132231404958678),
#  (('<20', 'mg/dL'), 0.004132231404958678),
#  (('=', '0.03),'), 0.004132231404958678),
#  (('API', '20'), 0.004132231404958678),
#  (('Antimicrobial', 'susceptibility'), 0.004132231404958678),
#  (('Antimicrobial', 'therapy'), 0.004132231404958678),
#  (('CSF', 'gram'), 0.004132231404958678),
#  (('CSF', 'leukocyte'), 0.004132231404958678),
#  (('Cerebrospinal', 'fluid'), 0.004132231404958678),
#  (('Computed', 'tomographic'), 0.004132231404958678),
#  (('Francisco', 'consumed'), 0.004132231404958678),
#  (('G', '24'), 0.004132231404958678),
#  (('Gram', 'stain'), 0.004132231404958678),
#  (('June', '2003'), 0.004132231404958678),
#  (('Philippines', 'June'), 0.004132231404958678),
#  (('Philippines', 'Three'), 0.004132231404958678),
#  (('Philippines', 'until'), 0.004132231404958678),
#  (('S.', 'suis'), 0.004132231404958678),
#  (('San', 'Francisco'), 0.004132231404958678),
#  (('Strep', 'System'), 0.004132231404958678),
#  (('Streptococcus', 'pneumoniae'), 0.004132231404958678),
#  (('Streptococcus', 'spp'), 0.004132231404958678),
#  (('Symptoms', 'continued'), 0.004132231404958678),
#  (('System', 'S.'), 0.004132231404958678),
#  (('Three', 'days'), 0.004132231404958678),
#  (('Two', 'months'), 0.004132231404958678),
#  (('admitted', 'local'), 0.004132231404958678),
#  (('after', 'discharge'), 0.004132231404958678),
#  (('after', 'symptoms'), 0.004132231404958678),
#  (('agglutination', 'test'), 0.004132231404958678),
#  (('aminopeptidase', 'negative'), 0.004132231404958678),
#  (('ampicillin', 'bacterial'), 0.004132231404958678),
#  (('and', 'clindamycin'), 0.004132231404958678),
#  (('and', 'vancomycin'), 0.004132231404958678),
#  (('anorexia', 'returned'), 0.004132231404958678),
#  (('antigen', 'Antimicrobial'), 0.004132231404958678),
#  (('antimicrobial', 'drugs'), 0.004132231404958678),
#  (('audiology', 'evaluation'), 0.004132231404958678),
#  (('bacterial', 'meningitis'), 0.004132231404958678),
#  (('bilateral', 'sensorineural'), 0.004132231404958678),
#  (('bile', 'esculin'), 0.004132231404958678),
#  (('blood', 'cultures'), 0.004132231404958678),
#  (('butcher', 'culinary'), 0.004132231404958678),
#  (('catalase', 'negative'), 0.004132231404958678),
#  (('ceftriaxone', 'vancomycin'), 0.004132231404958678),
#  (('ceftriaxone,', 'and'), 0.004132231404958678),
#  (('cells', '18%'), 0.004132231404958678),
#  (('chains', 'organism'), 0.004132231404958678),
#  (('chest', 'radiograph'), 0.004132231404958678),
#  (('clindamycin', 'Antimicrobial'), 0.004132231404958678),
#  (('cocci', 'in'), 0.004132231404958678),
#  (('cocci', 'pairs'), 0.004132231404958678),
#  (('consumed', 'raw'), 0.004132231404958678),
#  (('contact', 'with'), 0.004132231404958678),
#  (('continued', 'admitted'), 0.004132231404958678),
#  (('continued', 'oral'), 0.004132231404958678),
#  (('cooked', 'cooked'), 0.004132231404958678),
#  (('cooked', 'pork,'), 0.004132231404958678),
#  (('count', '21,000/mm3'), 0.004132231404958678),
#  (('count', '487/μL'), 0.004132231404958678),
#  (('course', 'parenteral'), 0.004132231404958678),
#  (('culinary', 'preference'), 0.004132231404958678),
#  (('cultures', 'gram'), 0.004132231404958678),
#  (('dB', '10'), 0.004132231404958678),
#  (('day', '2'), 0.004132231404958678),
#  (('day', '5'), 0.004132231404958678),
#  (('day', '7'), 0.004132231404958678),
#  (('day', '9'), 0.004132231404958678),
#  (('day', 'course'), 0.004132231404958678),
#  (('day', 'hospital'), 0.004132231404958678),
#  (('days', 'after'), 0.004132231404958678),
#  (('days', 'later'), 0.004132231404958678),
#  (('diaphoresis', 'headache'), 0.004132231404958678),
#  (('discharge', 'much'), 0.004132231404958678),
#  (('discharged', 'continued'), 0.004132231404958678),
#  (('doxycycline', 'Symptoms'), 0.004132231404958678),
#  (('drugs', 'discharged'), 0.004132231404958678),
#  (('ear', 'nasopharyngeal'), 0.004132231404958678),
#  (('eaten', 'Philippines'), 0.004132231404958678),
#  (('echocardiogram', 'negative'), 0.004132231404958678),
#  (('endoscopy', 'negative'), 0.004132231404958678),
#  (('esculin', 'negative'), 0.004132231404958678),
#  (('evaluation', 'severe'), 0.004132231404958678),
#  (('examination', 'slight'), 0.004132231404958678),
#  (('examination', 'somnolent'), 0.004132231404958678),
#  (('fever', '38.9°C'), 0.004132231404958678),
#  (('fever', 'diaphoresis'), 0.004132231404958678),
#  (('findings', 'neurologic'), 0.004132231404958678),
#  (('fluid', 'CSF'), 0.004132231404958678),
#  (('focal', 'findings'), 0.004132231404958678),
#  (('for', 'partially'), 0.004132231404958678),
#  (('formal', 'audiology'), 0.004132231404958678),
#  (('frequency', 'hearing'), 0.004132231404958678),
#  (('fully', 'oriented'), 0.004132231404958678),
#  (('glucose', 'protein'), 0.004132231404958678),
#  (('head', 'sinusitis'), 0.004132231404958678),
#  (('headache', 'malaise'), 0.004132231404958678),
#  (('headache', 'nausea'), 0.004132231404958678),
#  (('hearing', 'sequelae'), 0.004132231404958678),
#  (('high', 'frequency'), 0.004132231404958678),
#  (('history', 'was'), 0.004132231404958678),
#  (('hospital', '5'), 0.004132231404958678),
#  (('ill', 'fever'), 0.004132231404958678),
#  (('improved', 'hearing'), 0.004132231404958678),
#  (('in', 'pairs'), 0.004132231404958678),
#  (('intravenously', 'per'), 0.004132231404958678),
#  (('isolate', 'sensitive'), 0.004132231404958678),
#  (('later', 'fever'), 0.004132231404958678),
#  (('latex', 'agglutination'), 0.004132231404958678),
#  (('left', 'ear'), 0.004132231404958678),
#  (('local', 'hospital'), 0.004132231404958678),
#  (('loss', '70'), 0.004132231404958678),
#  (('loss', 'left'), 0.004132231404958678),
#  (('lymphocytes', 'glucose'), 0.004132231404958678),
#  (('malaise', 'no'), 0.004132231404958678),
#  (('man', 'San'), 0.004132231404958678),
#  (('medical', 'history'), 0.004132231404958678),
#  (('meningitis', 'Computed'), 0.004132231404958678),
#  (('mg/dL', '<167'), 0.004132231404958678),
#  (('mg/dL', 'Gram'), 0.004132231404958678),
#  (('million', 'units'), 0.004132231404958678),
#  (('month', 'vacation'), 0.004132231404958678),
#  (('months', 'after'), 0.004132231404958678),
#  (('much', 'improved'), 0.004132231404958678),
#  (('nasopharyngeal', 'endoscopy'), 0.004132231404958678),
#  (('nausea', 'anorexia'), 0.004132231404958678),
#  (('negative', 'Streptococcus'), 0.004132231404958678),
#  (('negative', 'bile'), 0.004132231404958678),
#  (('negative', 'pyrrolidonyl'), 0.004132231404958678),
#  (('neurologic', 'examination'), 0.004132231404958678),
#  (('neutrophils', 'Cerebrospinal'), 0.004132231404958678),
#  (('no', 'recent'), 0.004132231404958678),
#  (('of', 'symptoms'), 0.004132231404958678),
#  (('old', 'man'), 0.004132231404958678),
#  (('onset', 'doxycycline'), 0.004132231404958678),
#  (('onset', 'of'), 0.004132231404958678),
#  (('oral', 'therapy'), 0.004132231404958678),
#  (('organism', 'API'), 0.004132231404958678),
#  (('organism', 'catalase'), 0.004132231404958678),
#  (('oriented', 'focal'), 0.004132231404958678),
#  (('pairs', 'ceftriaxone'), 0.004132231404958678),
#  (('pairs', 'chains'), 0.004132231404958678),
#  (('parenteral', 'antimicrobial'), 0.004132231404958678),
#  (('partially', 'cooked'), 0.004132231404958678),
#  (('partially', 'partially'), 0.004132231404958678),
#  (('past', 'medical'), 0.004132231404958678),
#  (('penicillin', '(MIC'), 0.004132231404958678),
#  (('penicillin', 'G'), 0.004132231404958678),
#  (('per', 'day'), 0.004132231404958678),
#  (('persons', 'past'), 0.004132231404958678),
#  (('physical', 'examination'), 0.004132231404958678),
#  (('pneumoniae', 'antigen'), 0.004132231404958678),
#  (('polymorphonuclear', 'cells'), 0.004132231404958678),
#  (('pork', 'eaten'), 0.004132231404958678),
#  (('pork', 'traveling'), 0.004132231404958678),
#  (('pork,', 'pork'), 0.004132231404958678),
#  (('preference', 'for'), 0.004132231404958678),
#  (('prior', 'to'), 0.004132231404958678),
#  (('protein', '<20'), 0.004132231404958678),
#  (('pyrrolidonyl', 'aminopeptidase'), 0.004132231404958678),
#  (('radiograph', 'transesophageal'), 0.004132231404958678),
#  (('raw', 'pork'), 0.004132231404958678),
#  (('recent', 'contact'), 0.004132231404958678),
#  (('resistant', 'to'), 0.004132231404958678),
#  (('returned', '7'), 0.004132231404958678),
#  (('rigidity', 'headache'), 0.004132231404958678),
#  (('rigidity', 'leukocyte'), 0.004132231404958678),
#  (('scan', 'head'), 0.004132231404958678),
#  (('sensitive', 'to'), 0.004132231404958678),
#  (('sensorineural', 'high'), 0.004132231404958678),
#  (('serotype', '2'), 0.004132231404958678),
#  (('severe', 'bilateral'), 0.004132231404958678),
#  (('sick', 'persons'), 0.004132231404958678),
#  (('sinusitis', 'chest'), 0.004132231404958678),
#  (('slight', 'nuchal'), 0.004132231404958678),
#  (('somnolent', 'fully'), 0.004132231404958678),
#  (('spp', 'latex'), 0.004132231404958678),
#  (('stain', 'CSF'), 0.004132231404958678),
#  (('suis', 'serotype'), 0.004132231404958678),
#  (('susceptibility', 'testing'), 0.004132231404958678),
#  (('symptoms', 'hospital'), 0.004132231404958678),
#  (('symptoms', 'onset'), 0.004132231404958678),
#  (('test', 'Streptococcus'), 0.004132231404958678),
#  (('testing', 'isolate'), 0.004132231404958678),
#  (('tetracycline', 'and'), 0.004132231404958678),
#  (('the', 'week'), 0.004132231404958678),
#  (('therapy', 'Two'), 0.004132231404958678),
#  (('therapy', 'penicillin'), 0.004132231404958678),
#  (('to', 'onset'), 0.004132231404958678),
#  (('to', 'penicillin'), 0.004132231404958678),
#  (('to', 'tetracycline'), 0.004132231404958678),
#  (('tomographic', 'scan'), 0.004132231404958678),
#  (('transesophageal', 'echocardiogram'), 0.004132231404958678),
#  (('traveling', 'Philippines'), 0.004132231404958678),
#  (('units', 'intravenously'), 0.004132231404958678),
#  (('unremarkable', 'physical'), 0.004132231404958678),
#  (('until', 'the'), 0.004132231404958678),
#  (('vacation', 'Philippines'), 0.004132231404958678),
#  (('vancomycin', 'ampicillin'), 0.004132231404958678),
#  (('vancomycin', 'resistant'), 0.004132231404958678),
#  (('was', 'unremarkable'), 0.004132231404958678),
#  (('week', 'prior'), 0.004132231404958678),
#  (('with', 'sick'), 0.004132231404958678),
#  (('year', 'old'), 0.004132231404958678),
#  (('platelet', 'count'), 0.015209125475285171),
#  (('×', '109/L'), 0.015209125475285171),
#  (('esophageal', 'varices'), 0.011406844106463879),
#  (('32', 'to'), 0.0076045627376425855),
#  (('chain', 'reaction'), 0.0076045627376425855),
#  (('d', '32'), 0.0076045627376425855),
#  (('daily', 'd'), 0.0076045627376425855),
#  (('decompensated', 'liver'), 0.0076045627376425855),
#  (('g', 'daily'), 0.0076045627376425855),
#  (('intravenous', 'methylprednisolone'), 0.0076045627376425855),
#  (('liver', 'cirrhosis'), 0.0076045627376425855),
#  (('mg', 'daily'), 0.0076045627376425855),
#  (('polymerase', 'chain'), 0.0076045627376425855),
#  (('pulse', 'therapy'), 0.0076045627376425855),
#  (('(HLA)', 'genotyping'), 0.0038022813688212928),
#  (('1', 'g'), 0.0038022813688212928),
#  (('109/L', '69'), 0.0038022813688212928),
#  (('109/L', 'June'), 0.0038022813688212928),
#  (('109/L', 'just'), 0.0038022813688212928),
#  (('109/L', 'several'), 0.0038022813688212928),
#  (('11', 'diuretic'), 0.0038022813688212928),
#  (('13C', 'urea'), 0.0038022813688212928),
#  (('1995', 'Laboratory'), 0.0038022813688212928),
#  (('2000', 'liver'), 0.0038022813688212928),
#  (('2002', 'endoscopic'), 0.0038022813688212928),
#  (('2007', '8'), 0.0038022813688212928),
#  (('2007', 'admitted'), 0.0038022813688212928),
#  (('22', 'to'), 0.0038022813688212928),
#  (('24', 'response'), 0.0038022813688212928),
#  (('25', 'g'), 0.0038022813688212928),
#  (('3', 'ursodeoxycholic'), 0.0038022813688212928),
#  (('30', 'mg'), 0.0038022813688212928),
#  (('31', 'mild'), 0.0038022813688212928),
#  (('34', 'moderate'), 0.0038022813688212928),
#  (('36', 'second'), 0.0038022813688212928),
#  (('52', '×'), 0.0038022813688212928),
#  (('61', '×'), 0.0038022813688212928),
#  (('69', '×'), 0.0038022813688212928),
#  (('74', 'year'), 0.0038022813688212928),
#  (('8', '×'), 0.0038022813688212928),
#  (('900', 'mg'), 0.0038022813688212928),
#  (('A*02010101', 'B*400201'), 0.0038022813688212928),
#  (('B', 'C'), 0.0038022813688212928),
#  (('B*400201', 'C*030401'), 0.0038022813688212928),
#  (('Bone', 'marrow'), 0.0038022813688212928),
#  (('C', 'negative'), 0.0038022813688212928),
#  (('C*030401', 'C*07020101'), 0.0038022813688212928),
#  (('C*07020101', 'DPB1*0501'), 0.0038022813688212928),
#  (('DPB1*0501', 'DQA1*0103'), 0.0038022813688212928),
#  (('DQA1*0103', 'DQA1*030101'), 0.0038022813688212928),
#  (('DQA1*030101', 'DQB1*030201'), 0.0038022813688212928),
#  (('DQB1*030201', 'DQB1*060101'), 0.0038022813688212928),
#  (('DQB1*060101', 'DRB1*080201'), 0.0038022813688212928),
#  (('DRB1*080201', 'DRB1*080302'), 0.0038022813688212928),
#  (('DRB1*080302', '13C'), 0.0038022813688212928),
#  (('H', 'pylori'), 0.0038022813688212928),
#  (('Hepatitis', 'B'), 0.0038022813688212928),
#  (('Hepatitis', 'Hepatitis'), 0.0038022813688212928),
#  (('Histopathologic', 'examination'), 0.0038022813688212928),
#  (('Human', 'leukocyte'), 0.0038022813688212928),
#  (('ITP', 'Human'), 0.0038022813688212928),
#  (('ITP', 'day'), 0.0038022813688212928),
#  (('IgG', 'level'), 0.0038022813688212928),
#  (('IgM', 'presence'), 0.0038022813688212928),
#  (('January', 'and'), 0.0038022813688212928),
#  (('June', '2002'), 0.0038022813688212928),
#  (('June', '2007'), 0.0038022813688212928),
#  (('Laboratory', 'examinations'), 0.0038022813688212928),
#  (('November', '2000'), 0.0038022813688212928),
#  (('Oral', 'prednisolone'), 0.0038022813688212928),
#  (('PBC', 'Scheuer'), 0.0038022813688212928),
#  (('PBC', 'decompensated'), 0.0038022813688212928),
#  (('Scheuer', 'stage'), 0.0038022813688212928),
#  (('September', '2007'), 0.0038022813688212928),
#  (('Serologic', 'markers'), 0.0038022813688212928),
#  (('Ultrasonography', 'magnetic'), 0.0038022813688212928),
#  (('acid', '900'), 0.0038022813688212928),
#  (('admission', 'deterioration'), 0.0038022813688212928),
#  (('admission', 'purpura'), 0.0038022813688212928),
#  (('admitted', 'recurrent'), 0.0038022813688212928),
#  ...]

# %%
import spacy
import pandas as pd
import matplotlib.pyplot as plt

nlp = spacy.load('en_core_web_sm')

# Load stop words
stop_words = set(nltk.corpus.stopwords.words('english'))

all_tokens = []

for doc_id, doc in data.items():
    contents = doc['text']
    # tokenize the text
    tokens = nltk.word_tokenize(contents.lower())
    # remove stop words and punctuation
    tokens = [token for token in tokens if token not in stop_words and token.isalpha()]
    all_tokens.extend(tokens)

# create bigrams
bigrams = list(nltk.bigrams(all_tokens))
# create a bigram collocation finder
finder = BigramCollocationFinder.from_documents(bigrams)
# apply a scoring metric to rank the collocations
scored = finder.score_ngrams(BigramAssocMeasures().raw_freq)
# get the top 30 collocations
collocations = [' '.join(collocation) for collocation, score in scored[:30]]

# create a pandas dataframe with the collocations and their frequency
collocations_freq = [score for collocation, score in scored[:30]]
collocations = [' '.join(collocation) for collocation, score in scored[:30]]
df = pd.DataFrame({'collocation': collocations, 'frequency': collocations_freq})

# plot the collocations as a bar chart
plt.figure(figsize=(25, 20))
plt.rcParams.update({'font.size': 25})
plt.barh(df['collocation'], df['frequency'], color='blue')
plt.title('Top 30 Bigram Collocations')
plt.ylabel('Collocations')
plt.xlabel('Frequency score')
plt.tight_layout()  # optional, to improve spacing

plt.show()

# %% [markdown]
# ### Distribution of Entity types

# %%
import spacy
import pandas as pd
import matplotlib.pyplot as plt

# Load spaCy's English model
nlp = spacy.load('en_core_web_sm', disable=['ner'])

# Create an empty dictionary to store entity types and their counts
entity_counts = {}

# Loop through each document in your data dictionary
for doc_id, doc in data.items():
    contents = doc['text']
    annotations = doc['annotations']

    # Create a Doc object from the text
    doc = nlp(contents)
    prev_end = -1
    # Add your custom annotations to the Doc object
    for ann in annotations:
        label = ann["label"]
        start = ann["start"]
        end = ann["end"]
        if start > prev_end:
            span = doc.char_span(start, end, label=label)
            if span is not None:
                doc.ents += tuple([span])
        prev_end = end

    # Loop through each entity in the parsed document
    for ent in doc.ents:
        # If the entity type is not in the entity_counts dictionary, add it with a count of 1
        if ent.label_ not in entity_counts:
            entity_counts[ent.label_] = 1
        # If the entity type is already in the entity_counts dictionary, increment its count by 1
        else:
            entity_counts[ent.label_] += 1

# Convert the entity_counts dictionary to a pandas DataFrame for plotting
df = pd.DataFrame({'Entity Type': list(entity_counts.keys()), 'Count': list(entity_counts.values())})

# Sort the DataFrame by count in descending order
df = df.sort_values(by=['Count'], ascending=False)

# Plot the entity type counts as a bar chart
plt.rcParams.update({'font.size': 13})

plt.figure(figsize=(10, 12))
plt.barh(df['Entity Type'], df['Count'], color='blue')

plt.title('Distribution of Entity Types')
plt.ylabel('Entity Type')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# ### Analyzing the entity lengths, frequencies, and contexts.

# %%
# load the data
nlp = spacy.load('en_core_web_sm', disable=['ner'])

# get the entity lengths
entity_lengths = []
for doc_id in data:
    for ann in data[doc_id]['annotations']:
        entity_lengths.append(ann['end'] - ann['start'])

# get the entity frequencies
entity_frequencies = Counter()
for doc_id in data:
    for ann in data[doc_id]['annotations']:
        entity_frequencies[ann['label']] += 1

# get the entity contexts
entity_contexts = {}
for doc_id in data:
    doc = nlp(data[doc_id]['text'])

    for ann in data[doc_id]['annotations']:
        label = ann["label"]
        start = ann["start"]
        end = ann["end"]
        if start > prev_end:
            span = doc.char_span(start, end, label=label)
            if span is not None:
                doc.ents += tuple([span])
        prev_end = end

    for ent in doc.ents:
        label = ent.label_
        start = ent.start_char
        end = ent.end_char
        context = doc[max(0, start-5):end+5].text
        if label not in entity_contexts:
            entity_contexts[label] = []
        entity_contexts[label].append(context)

# print the results
print('Entity lengths:')
print('  Min:', min(entity_lengths))
print('  Max:', max(entity_lengths))
print('  Mean:', sum(entity_lengths)/len(entity_lengths))
print('Entity frequencies:')
for label, freq in entity_frequencies.items():
    print('  {}: {}'.format(label, freq))
print('Entity contexts:')
for label, contexts in entity_contexts.items():
    print('  {}:'.format(label))
    for context in contexts[:3]:
        if context:
            print('    - {}'.format(context))
# Out:
# Entity lengths:
#   Min: 1
#   Max: 54
#   Mean: 6.400996345283676
# Entity frequencies:
#   Age: 613
#   History: 1846
#   Sign_symptom: 4814
#   Sex: 191
#   Clinical_event: 757
#   Duration: 756
#   Coreference: 437
#   Frequency: 170
#   Detailed_description: 5319
#   Lab_value: 5005
#   Biological_structure: 5488
#   Diagnostic_procedure: 8364
#   Disease_disorder: 2209
#   Therapeutic_procedure: 1601
#   Date: 2112
#   Texture: 77
#   Biological_attribute: 13
#   Severity: 415
#   Activity: 179
#   Shape: 94
#   Color: 82
#   Outcome: 54
#   Personal_background: 73
#   Medication: 1444
#   Dosage: 991
#   Nonbiological_location: 695
#   Other_event: 94
#   Administration: 205
#   Occupation: 41
#   Other_entity: 327
#   Distance: 325
#   Time: 169
#   Area: 174
#   Family_history: 493
#   Subject: 78
#   Volume: 122
#   Quantitative_concept: 65
#   Height: 8
#   Weight: 8
#   Qualitative_concept: 56
#   Mass: 4
# Entity contexts:
#   Age:
#     - -old previously healthy man presented with a 6-week history of palpitations
#     - presented with a 6-week history of palpitations.
# The symptoms
#     - and a chronic cough.
# He was a smoker and had
#   History:
#     - -week history of palpitations.
# The symptoms occurred during rest, 2–3 times per week, lasted up
#     - rest, 2–3 times per week, lasted up to 30 minutes at a time and were
#     - (Fig.1).
# The tumor cells were strongly positive for S-100 protein, vimentin
#   Sex:
#     - up to 30 minutes at a time and were associated with dyspnea.
#     - was a smoker and had a history of pulmonary tuberculosis that had been
#     - presented with an acute two day history of malaise, fever, abdominal pain
#   Clinical_event:
#     - at a time and were associated with dyspnea.
# Except for a grade 2/6 holosystolic tricuspid regurgitation murmur
#     - the presence of Ebstein's anomaly of the tricuspid valve, with apical displacement
#   Duration:
#     - regurgitation murmur (best heard at the left sternal border with
#     - (best heard at the left sternal border with inspiratory accentuation), physical
#   Sign_symptom:
#     - unremarkable findings.
# An electrocardiogram (ECG) revealed normal sinus rhythm and a Wolff– Parkinson– White pre-
#     - ovale with right-to-left shunting and bubbles in the left atrium (Fig.2D)
#     - ).
# His post-ablation ECG showed a prolonged PR interval and an odd “second” QRS complex in leads
#   Coreference:
#     - – White pre-excitation pattern (Fig.1: Top), produced by a right-sided
#     - strongly positive for S-100 protein (Fig.5) and vimentin; they were also positive
#   Frequency:
#     - , with apical displacement of the valve and formation of an “atrialized” right
#     - valve and formation of an “atrialized” right ventricle (a functional
#     - an “atrialized” right ventricle (a functional unit between the right atrium
#   Detailed_description:
#     - atrium and the inlet [inflow] portion of the right ventricle
#     - inlet [inflow] portion of the right ventricle) (Fig.2
#     - ] portion of the right ventricle) (Fig.2).
#
#   Lab_value:
#     - an electrophysiologic study with mapping of the accessory pathway, followed by radiofrequency ablation (
#     - the accessory pathway, followed by radiofrequency ablation (interruption of the pathway
#   Biological_structure:
#     - by electromagnetic waves at the tip of an ablation catheter).
# His post-ablation ECG showed
#     - in the “atrialized” right ventricle.
# The patient reported no recurrence
#     - right ventricle.
# The patient reported no recurrence of palpitations at follow-up 6 months
#   Diagnostic_procedure:
#   Disease_disorder:
#   Therapeutic_procedure:
#   Date:
#   Texture:
#     - (Fig.6), and they were negative for cytokeratin, epithelial membrane antigen, CD3,
#     - 15% of the tumor cells.
# There was no staining for CK7.
#   Biological_attribute:
#     - the cytoplasm of the tumor cells.
# Now, at five months after lobectomy
#     - .
# Now, at five months after lobectomy, the patient is doing well with no significant change in the radiologic
#   Severity:
#   Activity:
#     - doxycycline.
# Symptoms continued and he was admitted to a local hospital 5 days later with a
#   Shape:
#   Color:
#   Outcome:
#   Personal_background:
#     - year history of Crohn's disease presented with an acute two day history of malaise
#     - just returned from a 7-month vacation in the Philippines.
#
#     - 7-month vacation in the Philippines.
# Three days after symptoms onset, his physician prescribed doxycycline
#   Medication:
#   Dosage:
#   Nonbiological_location:
#     - sick persons; past medical history was unremarkable.
# On physical examination, he was somnolent but fully oriented,
#     - gram-positive cocci in pairs and chains.
# The organism was catalase-negative, bile esculin-negative
#   Other_event:
#   Administration:
#   Occupation:
#     - preponderance of microliths in the lower lobes.
# There were associated areas of interlobular septal
#     - .
# There were associated areas of interlobular septal thickening and ground-glass changes.
#   Distance:
#   Time:
#     - perforation.
# A flexible sigmoidoscopy was performed under conscious sedation.
#     - A flexible sigmoidoscopy was performed under conscious sedation.
# The
#     - sigmoidoscopy was performed under conscious sedation.
# The object was located just above the
#   Area:
#   Family_history:
#     - ’ gestation by cesarean section.
# His mother (primipara, 32 years old) had
#     - mother (primipara, 32 years old) had been admitted to our hospital 2 weeks previously because of reduced fetal intrauterine movements and polyhydramnios.
#
#     - of reduced fetal intrauterine movements and polyhydramnios.
# The child’s birthweight was 2,330 g (
#   Subject:
#     - with severe hypotonia and generalized muscle weakness, requiring ventilatory assistance and total parenteral nutrition.
#   Volume:
#   Quantitative_concept:
#   Other_entity:
#   Height:
#     - .
# After surgery, the cardiac function improved drastically (cardiothoracic ratio=0.47
#     - , the cardiac function improved drastically (cardiothoracic ratio=0.47; EF=0.55 in
#     - ; (b) small chest, as determined by a cardiothoracic examination
#   Weight:
#     - of ventricular arrhythmias decreased and pimobendan was tapered off.
#
#     - decreased and pimobendan was tapered off.
#
#     - was not being maintained and that he was functioning at the 6–8 month developmental
#   Qualitative_concept:
#     - disoriented.
# His axillary body temperature was 35.7 °C and his arterial blood pressure
#     - 35.7 °C and his arterial blood pressure 125/89 mm Hg, with a pulse rate
#     - ; ejection fraction, 36.6%; and LV mass index, 75.6 g (Z = 6.3;
#   Mass:
#     - (Fig.2).
# During endoscopy a pedicle was not
#     - ).
# During endoscopy a pedicle was not identify by handling

# %% [markdown]
# ### Check for overlapping entities:

# %%
multi_label_words_count = 0
multi_label_files_count = 0
for file_id in data:
    annotations = data[file_id]['annotations']
    overlapping = False

    for i in range(len(annotations)-1):
        if annotations[i]['end'] >= annotations[i+1]['start']:
            overlapping = True
            multi_label_words_count += 1
            # print(f"Overlap found between {annotations[i]} and {annotations[i+1]}")

    if overlapping:
        multi_label_files_count += 1

print(f"Total number of words with multi labels found is {multi_label_words_count}")
print(f"Total number of files with multi labelled words is {multi_label_files_count}")
# Out:
# Total number of words with multi labels found is 826
# Total number of files with multi labelled words is 105

# %%
total_count = 0
overlapping_count_dict = {}
for doc_id in data:

    overlapping_count = 0

    text = data[doc_id]['text']

    annotations = data[doc_id]['annotations']

    for i in range(len(annotations)-1):
        label = annotations[i]['label']
        start = annotations[i]['start']
        end = annotations[i]['end']

        if annotations[i]['end'] > annotations[i+1]['start']:
            total_count += 1
            overlapping_count += 1
    overlapping_count_dict[doc_id] = overlapping_count

# %%
import matplotlib.pyplot as plt

sorted_dict = dict(sorted(overlapping_count_dict.items(), key=lambda item: item[1], reverse=True)[:20])
doc_ids = list(sorted_dict.keys())
overlapping_counts = list(sorted_dict.values())

fig, ax = plt.subplots(figsize=(12,6))


ax.set_xlabel('Doc ID')
ax.set_ylabel('Overlapping Entity Count')
ax.set_title('Top 20 Documents by Overlapping Entity Count')
ax.set_xticks(range(len(doc_ids)))  # set the tick locations
ax.set_xticklabels(doc_ids, rotation=45, ha='right')  # set the tick labels
ax.bar(doc_ids, overlapping_counts)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# create the entity_ranges dictionary
entity_ranges = {}
max_end_of_text = 0

for doc_id in data:
    text = data[doc_id]['text']
    if len(text) > max_end_of_text:
        max_end_of_text = len(text)

    annotations = data[doc_id]['annotations']
    doc_entity_ranges = []
    for ann in annotations:
        start = ann['start']
        end = ann['end']
        doc_entity_ranges.append((start, end))
    entity_ranges[doc_id] = doc_entity_ranges

# create the heatmap with overlapping intensity levels
heatmap = np.zeros((len(entity_ranges), max_end_of_text))
row = 0
for doc_id, doc_entity_ranges in entity_ranges.items():
    for start, end in doc_entity_ranges:
        for i in range(start, end):
            heatmap[row][i] += 1
    row += 1
# plot the heatmap with Seaborn
plt.figure(figsize=(12, 10))
ax = sns.heatmap(heatmap, cmap='Reds', cbar_kws={'label': 'Intensity'})
ax.set_xlabel('Position')
ax.set_ylabel('Document ID')
ax.set_title('Heatmap of Overlapping Entities with Intensity Levels')

plt.show()

# %% [markdown]
# ### Checking if subwords overlaps
#
# Checking if there are any annotated start_end_range partially overlapping

# %%
for file_id in data:
    annotations = data[file_id]['annotations']
    overlapping = False

    for i in range(len(annotations)-1):
        if annotations[i]['end'] > annotations[i+1]['start']:
            overlapping = True
            word_1 = data[file_id]['text'][annotations[i]['start']:annotations[i]['end']]
            word_2 = data[file_id]['text'][annotations[i+1]['start']:annotations[i+1]['end']]

            if word_1 != word_2:
                print(f"part of words overlaps: {word_1} {word_2}")
#                 print(f"labels: {file_id} {annotations[i]['label']} {annotations[i]['start']} {annotations[i]['end']}, {annotations[i+1]['label']} {annotations[i+1]['start']} {annotations[i+1]['end']}")
# Out:
# part of words overlaps: pork, pork
# part of words overlaps: hepatitis hepatitis,
# part of words overlaps: long ong
# part of words overlaps: insufficiency insufficiency,
# part of words overlaps: sarcoma sarcoma,
# part of words overlaps: cholecystectomy, cholecystectomy
# part of words overlaps: IIA, IIA
# part of words overlaps: T1bN1, T1bN1
# part of words overlaps: walking walking,
# part of words overlaps: (LV) LV
# part of words overlaps: smoking smoking,
# part of words overlaps: output, output
# part of words overlaps: dialysis, dialysis
# part of words overlaps: intolerance, intolerance
# part of words overlaps: palpitation, palpitation
# part of words overlaps: sibling, sibling
# part of words overlaps: bacteria bacteria,
# part of words overlaps: consanguineous consanguineous,
# part of words overlaps: old old,
# part of words overlaps: symmetry, symmetry
# part of words overlaps: trauma trauma,
# part of words overlaps: intake intake,
# part of words overlaps: drugs drugs,
# part of words overlaps: tobacco tobacco,
# part of words overlaps: drugs drugs,
# part of words overlaps: (HBV) HBV
# part of words overlaps: GD GD,
# part of words overlaps: diarrhoea, diarrhoea
# part of words overlaps: student student,
# part of words overlaps: months months’
# part of words overlaps: years years.

# %% [markdown]
# data

# %%
# Count number of files starting and ending with punctuation
start_punct_count = 0
end_punct_count = 0
neither_punct_count = 0

# Loop through each file in the data dictionary
for file_id, file_data in data.items():

    for annotation in file_data['annotations']:

        # Get the annotated text
        annotated_text = file_data['text'][annotation['start']:annotation['end']]
        # Check if the first or last character of the annotated text is a punctuation character
        if annotated_text[0] in string.punctuation:
            start_punct_count += 1
        elif annotated_text[-1] in string.punctuation:
            end_punct_count += 1
        else:
            neither_punct_count += 1

# Print counts in table format
print('{:<25}{}'.format('Category', 'Count'))
print('-'*35)
print('{:<25}{}'.format('Starts with punctuation', start_punct_count))
print('{:<25}{}'.format('Ends with punctuation', end_punct_count))
print('{:<25}{}'.format('Neither', neither_punct_count))
# Out:
# Category                 Count
# -----------------------------------
# Starts with punctuation  158
# Ends with punctuation    512
# Neither                  45298

# %% [markdown]
# #### Removing Trailing Punctuation

# %%
def remove_trailing_punctuation(token):
    """
    Removes trailing punctuation from a token.

    Args:
        token (str): A string representing the token to be cleaned.

    Returns:
        str: The cleaned token with trailing punctuation removed.
    """
    while token and re.search(r'[^\w\s\']', token[-1]):
        token = token[:-1]

    return token

# %%
for file_id in data:
    annotations = data[file_id]['annotations']
    overlapping = False

    for i in range(len(annotations)-1):
        if annotations[i]['end'] > annotations[i+1]['start']:
            overlapping = True
            word_1 = data[file_id]['text'][annotations[i]['start']:annotations[i]['end']]
            word_2 = data[file_id]['text'][annotations[i+1]['start']:annotations[i+1]['end']]

            if remove_trailing_punctuation(word_1) != remove_trailing_punctuation(word_2):
                print(f"doc_id: {file_id} words: {word_1} {word_2}", end=" | ")
                print(f"labels: {file_id} {annotations[i]['label']} {annotations[i]['start']} {annotations[i]['end']}, {annotations[i+1]['label']} {annotations[i+1]['start']} {annotations[i+1]['end']}")
# Out:
# doc_id: 19214295 words: long ong | labels: 19214295 Detailed_description 424 428, History 425 428
# doc_id: 23468586 words: (LV) LV | labels: 23468586 History 314 318, Disease_disorder 315 317
# doc_id: 27749582 words: (HBV) HBV | labels: 27749582 History 253 258, Detailed_description 254 257

# %% [markdown]
# Fixing "doc_id: 19214295 words: long ong | labels: 19214295 Detailed_description 424 428, History 425 428"

# %%
for annotation in data['19214295']['annotations']:
    if annotation['start'] == 425:
        annotation['start'] = 424

# %% [markdown]
# ### Saving data dictionary to a json file

# %%
def create_json(preprocessed_data_dir, data):

    if os.path.exists(preprocessed_data_dir):
        # Delete the contents of the directory
        shutil.rmtree(preprocessed_data_dir)
    # Recreate the directory
    os.makedirs(preprocessed_data_dir)

    # Write the dictionary to a JSON file
    with open(os.path.join(preprocessed_data_dir, "annotated_data.json"), "w") as f:
        json.dump(data, f)

# %%
preprocessed_data_dir = "data/annotated_json_data"
create_json(preprocessed_data_dir, data)
